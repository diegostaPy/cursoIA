# %% [markdown]
# # Stock Predictor RNN
#
# Predicción de las acciones de Apple

# %% [markdown]
# ## Carga de datos
#
# Primero carguemos nuestra serie temporal: un historial de alrededor de 140 días del precio de las acciones de Apple. Luego, debemos realizar una serie de pasos de preprocesamiento para prepararlo para su uso con un modelo RNN. En primer lugar, es una buena práctica normalizar las series de tiempo, normalizando su rango. Esto nos ayuda a evitar problemas numéricos graves asociados con la forma en que las funciones de activación comunes (como tanh) transforman números muy grandes (positivos o negativos), además de ayudarnos a evitar problemas relacionados al calcular derivadas.
#
# Datos normalizados [0,1] [using this scikit function](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html).

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv('Sunspots.csv',names=['id','date','n'],skiprows=1)
# Out:
# D:\UserFiles\anaconda\envs\ia\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# D:\UserFiles\anaconda\envs\ia\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# D:\UserFiles\anaconda\envs\ia\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:\n%s" %

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3265 entries, 0 to 3264
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3265 non-null   int64
#  1   date    3265 non-null   object
#  2   n       3265 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.6+ KB

# %%
dataset.head()
# Out:
#    id        date      n
# 0   0  1749-01-31   96.7
# 1   1  1749-02-28  104.3
# 2   2  1749-03-31  116.7
# 3   3  1749-04-30   92.8
# 4   4  1749-05-31  141.7

# %%
dataset.tail(134)
# Out:
#         id        date     n
# 3131  3131  2009-12-31  16.3
# 3132  3132  2010-01-31  19.5
# 3133  3133  2010-02-28  28.5
# 3134  3134  2010-03-31  24.0
# 3135  3135  2010-04-30  10.4
# ...    ...         ...   ...
# 3260  3260  2020-09-30   0.6
# 3261  3261  2020-10-31  14.4
# 3262  3262  2020-11-30  34.0
# 3263  3263  2020-12-31  21.8
# 3264  3264  2021-01-31  10.4
#
# [134 rows x 3 columns]

# %% [markdown]
# Visualizacion de los datos

# %%
plt.plot(dataset.n.values)
plt.xlabel('tiempo')
plt.ylabel('serie normalizada')
# Out:
# Text(0, 0.5, 'serie normalizada')

# %%
rango=np.max(dataset.n.values)-np.min(dataset.n.values)
minimo=np.min(dataset.n.values)

# %%
plt.plot((dataset.n.values-minimo)/rango*2-1)
plt.xlabel('tiempo')
plt.ylabel('serie normalizada')
# Out:
# Text(0, 0.5, 'serie normalizada')

# %%
dataset['nnorm']=(dataset.n.values-minimo)/rango*2-1

# %% [markdown]
# ## Paso 2:  Cortando las series en secuencias
# Recuerde, nuestra serie de tiempo es una secuencia de números que podemos representar matemáticamente en general como
# $$s_{0},s_{1},s_{2},...,s_{P}$$
#
# donde $ s_ {p} $ es el valor numérico de la serie de tiempo en el período de tiempo $ p $ y donde $ P $ es la longitud total de la serie. Para aplicar nuestro RNN, tratamos el problema de predicción de series de tiempo como un problema de regresión, por lo que necesitamos usar una ventana deslizante para construir un conjunto de pares de entrada / salida asociados para retroceder. Este proceso está animado en el gif a continuación.
#
# <img src="images/timeseries_windowing_training.gif" width=600 height=600/>
#
# Por ejemplo, utilizando una ventana de tamaño T = 5 (como se ilustra en el gif anterior) producimos un conjunto de pares de entrada / salida como el que se muestra en la tabla a continuación.
#
# $$\begin{array}{c|c}
# \text{Input} & \text{Output}\\
# \hline \color{CornflowerBlue} {\langle s_{1},s_{2},s_{3},s_{4},s_{5}\rangle} & \color{Goldenrod}{ s_{6}} \\
# \ \color{CornflowerBlue} {\langle s_{2},s_{3},s_{4},s_{5},s_{6} \rangle } & \color{Goldenrod} {s_{7} } \\
# \color{CornflowerBlue}  {\vdots} & \color{Goldenrod} {\vdots}\\
# \color{CornflowerBlue} { \langle s_{P-5},s_{P-4},s_{P-3},s_{P-2},s_{P-1} \rangle } & \color{Goldenrod} {s_{P}}
# \end{array}$$
#
# Observe aquí que cada entrada es una secuencia (o vector) de longitud 4 (y en general tiene una longitud igual al tamaño de ventana T) mientras que cada salida correspondiente es un valor escalar. Observe también cómo, dada una serie de tiempo de longitud P y tamaño de ventana T = 5 como se muestra arriba, creamos P - 5 pares de entrada / salida. De manera más general, para un tamaño de ventana T creamos P - T tales pares.
#
# ¡Ahora veamos la serie de tiempo de entrada como se describe arriba!

# %%
### The function below transforms the input series and window-size into a set of input/output pairs for our RNN model
def window_transform_series(series,window_size):
    # containers for input/output pairs
    X = []
    y = []
    
    for i in range(window_size, len(series)):
        X.append(series[i - window_size:i])
        y.append(series[i])
        
        
    # reshape each 
    X = np.asarray(X)
    X.shape = (np.shape(X)[0:2])
    y = np.asarray(y)
    y.shape = (len(y),1)
    
    return X,y

# %%
# And now we can window the data using our windowing function
window_size = 132
X,y = window_transform_series(series = dataset.nnorm.values,window_size = window_size)

# %% [markdown]
# ## Paso 3: Separar Train y Test
#
# Para realizar las pruebas adecuadas en nuestro conjunto de datos, cortaremos el último 1/3 para su validación (o prueba).
#
# Tenga en cuenta que aquí ** no ** dividimos el conjunto de datos * aleatoriamente * como se haría normalmente al validar un modelo de regresión. Esto se debe a que nuestros pares de entrada / salida * están relacionados temporalmente *. No queremos validar nuestro modelo entrenando en un subconjunto aleatorio de la serie y luego probando en otro subconjunto aleatorio, ya que esto simula el escenario en el que recibimos nuevos puntos * dentro del marco de tiempo de nuestro conjunto de entrenamiento *.
#
# Queremos entrenar en una parte sólida de la serie (en nuestro caso, los primeros 2/3 completos) y validar en una parte posterior (el último 1/3), ya que esto simula cómo predeciríamos los valores * futuros *. de una serie de tiempo.

# %%
# split our dataset into training / testing sets
#train_test_split =-134 #int(np.ceil(2*len(y)/float(3)))   # set the split point

# partition the training set
X_train = X[:-134,:]
y_train = y[:-134]

# keep the last chunk for testing
X_test = X[-134:,:]
y_test = y[-134:]

# NOTE: to use keras's RNN LSTM module our input must be reshaped to [samples, window size, stepsize] 
X_train = np.asarray(np.reshape(X_train, (X_train.shape[0], window_size, 1)))
X_test = np.asarray(np.reshape(X_test, (X_test.shape[0], window_size, 1)))

# %%
from tensorflow.python.client import device_lib
import tensorflow as tf

print(device_lib.list_local_devices())
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14779888521337818887
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1383113934
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9633005702818851646
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]
# Num GPUs Available:  1

# %% [markdown]
# ## Step 4:  Construir y entrenar una RNN
#
#
# Después de haber creado pares de entrada / salida a partir de nuestra serie de tiempo y cortar esto en conjuntos de entrenamiento / prueba, ahora podemos comenzar a configurar nuestro RNN. Usamos Keras para construir rápidamente un RNN de dos capas ocultas de las siguientes especificaciones
#
# - layer 1 uses an LSTM module with 5 hidden units (note here the input_shape = (window_size,1))
# - layer 2 uses a fully connected module with one unit
# - the 'mean_squared_error' loss should be used

# %%
# import keras network libraries
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.compat.v1.keras import backend as Kc

config = tf.compat.v1.ConfigProto( device_count = {'GPU': 1 , 'CPU': 56} ) 
sess = tf.compat.v1.Session(config=config) 
Kc.set_session(sess)
#tf.config.experimental.set_memory_growth(
 #   device, enable
#)



# start with fixed random seed
np.random.seed(0)


# Build an RNN to perform regression on our time series input/output data
model = Sequential()
model.add(LSTM(5, input_shape=(window_size, 1)))
model.add(Dense(1))

optimizer = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)

# compile the model
model.compile(loss='mean_squared_error', optimizer=optimizer)
# Out:
# C:\Users\yoda\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5)                 140
# _________________________________________________________________
# dense (Dense)                (None, 1)                 6
# =================================================================
# Total params: 146
# Trainable params: 146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Ahora podemos entrenar el modelo

# %%
model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1)
# Out:
# Epoch 1/500
# 47/47 [==============================] - 6s 17ms/step - loss: 0.2311
# Epoch 2/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0673
# Epoch 3/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0320
# Epoch 4/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0216
# Epoch 5/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0189
# Epoch 6/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0178
# Epoch 7/500
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0173
# Epoch 8/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0170
# Epoch 9/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0168
# Epoch 10/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0166
# Epoch 11/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0165
# Epoch 12/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0164
# Epoch 13/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0162
# Epoch 14/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0161
# Epoch 15/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0160
# Epoch 16/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0159
# Epoch 17/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0158
# Epoch 18/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0158
# Epoch 19/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0157
# Epoch 20/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0157
# Epoch 21/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0157
# Epoch 22/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0156
# Epoch 23/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0156
# Epoch 24/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0155
# Epoch 25/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0155
# Epoch 26/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0155
# Epoch 27/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0154
# Epoch 28/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0154
# Epoch 29/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0153
# Epoch 30/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0153
# Epoch 31/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0153
# Epoch 32/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0153
# Epoch 33/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0152
# Epoch 34/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0153: 0s - l
# Epoch 35/500
# 47/47 [==============================] - ETA: 0s - loss: 0.015 - 1s 13ms/step - loss: 0.0152
# Epoch 36/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0152
# Epoch 37/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0152
# Epoch 38/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0151: 0s - loss: 0.0
# Epoch 39/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0151
# Epoch 40/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0151
# Epoch 41/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0151
# Epoch 42/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0151
# Epoch 43/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0151
# Epoch 44/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0151
# Epoch 45/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0150
# Epoch 46/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0151
# Epoch 47/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0151
# Epoch 48/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0150
# Epoch 49/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0150
# Epoch 50/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0150
# Epoch 51/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0150
# Epoch 52/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0150
# Epoch 53/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0150
# Epoch 54/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0150
# Epoch 55/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0150
# Epoch 56/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0150
# Epoch 57/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0150
# Epoch 58/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0150
# Epoch 59/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0149
# Epoch 60/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0150: 0s - loss: 0.0
# Epoch 61/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0149
# Epoch 62/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0150
# Epoch 63/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 64/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 65/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 66/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 67/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 68/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 69/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0149
# Epoch 70/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 71/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 72/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 73/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 74/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0149
# Epoch 75/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0149
# Epoch 76/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0149
# Epoch 77/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0149: 0s - loss: 0.0
# Epoch 78/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 79/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0148
# Epoch 80/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 81/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0149
# Epoch 82/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0148
# Epoch 83/500
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0148
# Epoch 84/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 85/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0149
# Epoch 86/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 87/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 88/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 89/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 90/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 91/500
# 47/47 [==============================] - ETA: 0s - loss: 0.014 - 1s 14ms/step - loss: 0.0149
# Epoch 92/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 93/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 94/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 95/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 96/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 97/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 98/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0148
# Epoch 99/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 100/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0148
# Epoch 101/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 102/500
# 47/47 [==============================] - ETA: 0s - loss: 0.014 - 1s 13ms/step - loss: 0.0148
# Epoch 103/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 104/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0148
# Epoch 105/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0147
# Epoch 106/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 107/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0148
# Epoch 108/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 109/500
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0148
# Epoch 110/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0148
# Epoch 111/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0148
# Epoch 112/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0148
# Epoch 113/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0148
# Epoch 114/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 115/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 116/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0148
# Epoch 117/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0148
# Epoch 118/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 119/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 120/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 121/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 122/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0147
# Epoch 123/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 124/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0147
# Epoch 125/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0148
# Epoch 126/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 127/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0147
# Epoch 128/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 129/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0148
# Epoch 130/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 131/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 132/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 133/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0147
# Epoch 134/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0147
# Epoch 135/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0148
# Epoch 136/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 137/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 138/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0147
# Epoch 139/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 140/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0147
# Epoch 141/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 142/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 143/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 144/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 145/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 146/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 147/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0148
# Epoch 148/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 149/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 150/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 151/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 152/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 153/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 154/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 155/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 156/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 157/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 158/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 159/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 160/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 161/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 162/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 163/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 164/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 165/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 166/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 167/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 168/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 169/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 170/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0147
# Epoch 171/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 172/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 173/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146: 0s - loss: 0.014
# Epoch 174/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 175/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 176/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 177/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 178/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 179/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 180/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 181/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 182/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 183/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 184/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 185/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 186/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 187/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 188/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 189/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 190/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 191/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 192/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0146
# Epoch 193/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 194/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 195/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 196/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 197/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 198/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 199/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 200/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 201/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 202/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0147
# Epoch 203/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 204/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0146
# Epoch 205/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0146
# Epoch 206/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 207/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 208/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 209/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 210/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0146
# Epoch 211/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0146
# Epoch 212/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 213/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 214/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0146
# Epoch 215/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 216/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 217/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 218/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0147
# Epoch 219/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 220/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 221/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 222/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 223/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 224/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 225/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0146
# Epoch 226/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 227/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 228/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 229/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 230/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 231/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 232/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 233/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 234/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0146
# Epoch 235/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 236/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 237/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 238/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0146
# Epoch 239/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 240/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 241/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 242/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 243/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 244/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 245/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 246/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 247/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 248/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145: 0s - loss:
# Epoch 249/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 250/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146: 0s - loss: 0.0
# Epoch 251/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 252/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 253/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0146
# Epoch 254/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 255/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 256/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146: 0s - loss
# Epoch 257/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 258/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 259/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 260/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0146
# Epoch 261/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 262/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 263/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 264/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 265/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 266/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 267/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 268/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 269/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 270/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 271/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 272/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 273/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 274/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 275/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0146
# Epoch 276/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 277/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 278/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 279/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 280/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0145
# Epoch 281/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 282/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 283/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 284/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 285/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 286/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0146
# Epoch 287/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 288/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 289/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 290/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 291/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 292/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 293/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0146
# Epoch 294/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 295/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 296/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 297/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 298/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 299/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 300/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0145
# Epoch 301/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 302/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 303/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 304/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 305/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 306/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 307/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 308/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 309/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 310/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145: 0s - l
# Epoch 311/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 312/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 313/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 314/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 315/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 316/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 317/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 318/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 319/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 320/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 321/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 322/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 323/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 324/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 325/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 326/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 327/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 328/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 329/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 330/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 331/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 332/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 333/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 334/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 335/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 336/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 337/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 338/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 339/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 340/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 341/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 342/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 343/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0145
# Epoch 344/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 345/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 346/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 347/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 348/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145: 0s - loss: 0.014
# Epoch 349/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 350/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 351/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 352/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 353/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 354/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 355/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 356/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 357/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 358/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 359/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 360/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 361/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0145
# Epoch 362/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 363/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144: 0s - lo
# Epoch 364/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 365/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 366/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 367/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 368/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 369/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 370/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 371/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 372/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 373/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 374/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 375/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 376/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 377/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 378/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 379/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 380/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 381/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 382/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 383/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 384/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0144
# Epoch 385/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 386/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 387/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 388/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 389/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 390/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 391/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 392/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 393/500
# 47/47 [==============================] - ETA: 0s - loss: 0.014 - 1s 15ms/step - loss: 0.0144
# Epoch 394/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 395/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0145
# Epoch 396/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144: 0s - loss: 0.
# Epoch 397/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 398/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 399/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 400/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 401/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 402/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 403/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 404/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 405/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 406/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 407/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 408/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 409/500
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0144
# Epoch 410/500
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0144
# Epoch 411/500
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0144
# Epoch 412/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0145
# Epoch 413/500
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0144
# Epoch 414/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 415/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 416/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 417/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 418/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 419/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 420/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0145
# Epoch 421/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144: 0s - loss: 0.014
# Epoch 422/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 423/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 424/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 425/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 426/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 427/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0145
# Epoch 428/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 429/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 430/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 431/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 432/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 433/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 434/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 435/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 436/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 437/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 438/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 439/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 440/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 441/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 442/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 443/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 444/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 445/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 446/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 447/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 448/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 449/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 450/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 451/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 452/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 453/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 454/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 455/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0144
# Epoch 456/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 457/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 458/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 459/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 460/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 461/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 462/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 463/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 464/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 465/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 466/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 467/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 468/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 469/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 470/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 471/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 472/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 473/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 474/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 475/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 476/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 477/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 478/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 479/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0143
# Epoch 480/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 481/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 482/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 483/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 484/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 485/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 486/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 487/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 488/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 489/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 490/500
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0144
# Epoch 491/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 492/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 493/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 494/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 495/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 496/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0144
# Epoch 497/500
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0144
# Epoch 498/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 499/500
# 47/47 [==============================] - 1s 14ms/step - loss: 0.0144
# Epoch 500/500
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0143

# %% [markdown]
# ## Paso 5: Verificando el modelo
#
#
# With our model fit we can now make predictions on both our training and testing sets.

# %%
# generate predictions for training
train_predict = (model.predict(X_train)+1)/2*rango+minimo
test_predict =( model.predict(X_test)+1)/2*rango+minimo

# %%
from sklearn.metrics import mean_squared_error

# %%
# print out training and testing errors
training_error = mean_squared_error(train_predict,(y_train+1)/2*rango+minimo)
print('training error = ' + str(training_error))

testing_error =  mean_squared_error(test_predict,(y_test+1)/2*rango+minimo)
print('testing error = ' + str(testing_error))
# Out:
# training error = 572.546339992694
# testing error = 243.87770880442656

# %%
### Plot everything - the original series as well as predictions on training and testing sets
import matplotlib.pyplot as plt
# %matplotlib inline
train_test_split=3265-2*133
# plot original series
plt.plot(dataset.n,color = 'k')

split_pt = train_test_split + window_size 
plt.plot(np.arange(window_size,split_pt,1),train_predict,color = 'b')

# plot testing set prediction
plt.plot(np.arange(split_pt,split_pt + len(test_predict),1),test_predict,color = 'r')

#
# pretty up graph
plt.xlabel('month')
plt.ylabel('Sunspots')
plt.legend(['original series','training fit','testing fit'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
### Plot everything - the original series as well as predictions on training and testing sets
import matplotlib.pyplot as plt
# %matplotlib inline
train_test_split=3265-2*133
# plot original series
plt.plot(np.arange(split_pt,split_pt + len(test_predict),1),dataset.n.values[np.arange(split_pt,split_pt + len(test_predict),1)],color = 'k')
# plot testing set prediction
plt.plot(np.arange(split_pt,split_pt + len(test_predict),1),test_predict,color = 'r')

#
# pretty up graph
plt.xlabel('month')
plt.ylabel('Sunspots')
plt.legend(['original series','testing fit'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
yc24=np.concatenate((dataset.nnorm.values[-132:], model.predict(X_test).reshape(-1)), axis=0)

# %%
Xc24,yc24 = window_transform_series(series =yc2425 ,window_size = window_size)

# %%
np.shape(Xc24)
# Out:
# (135, 132)

# %%
X_c24 = np.asarray(np.reshape(Xc24, (Xc24.shape[0], window_size, 1)))

# %%
predict25 =( model.predict(X_c24)+1)/2*rango+minimo

# %%
dataset['date'] = pd.to_datetime(dataset['date'].astype(str),format='%Y-%m-%d')
dataset.set_index(["date"],drop=False, inplace=True)

# %%
### Plot everything - the original series as well as predictions on training and testing sets
import matplotlib.pyplot as plt
# %matplotlib inline
train_test_split=3265-2*133
# plot original series
plt.plot(dataset.date.values[np.arange(split_pt-800,split_pt + len(test_predict),1)],dataset.n.values[np.arange(split_pt-800,split_pt + len(test_predict),1)],color = 'k')
# plot testing set prediction
plt.plot(dataset.date.values[np.arange(split_pt,split_pt + len(test_predict),1)],test_predict,color = 'r')

plt.plot(dataset.date.shift(132, freq="MS").index.values[np.arange(split_pt-1,split_pt + len(test_predict),1)],predict25,color = 'r')

#
# pretty up graph
plt.xlabel('')
plt.ylabel('Sunspots')
plt.legend(['original series','test fit','cycle25'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
split_pt
# Out:
# 3131

# %%
dataset.date.shift(132, freq="MS").values[np.arange(split_pt,split_pt+ len(test_predict),1)]
# Out:
# array(['2009-12-31T00:00:00.000000000', '2010-01-31T00:00:00.000000000',
#        '2010-02-28T00:00:00.000000000', '2010-03-31T00:00:00.000000000',
#        '2010-04-30T00:00:00.000000000', '2010-05-31T00:00:00.000000000',
#        '2010-06-30T00:00:00.000000000', '2010-07-31T00:00:00.000000000',
#        '2010-08-31T00:00:00.000000000', '2010-09-30T00:00:00.000000000',
#        '2010-10-31T00:00:00.000000000', '2010-11-30T00:00:00.000000000',
#        '2010-12-31T00:00:00.000000000', '2011-01-31T00:00:00.000000000',
#        '2011-02-28T00:00:00.000000000', '2011-03-31T00:00:00.000000000',
#        '2011-04-30T00:00:00.000000000', '2011-05-31T00:00:00.000000000',
#        '2011-06-30T00:00:00.000000000', '2011-07-31T00:00:00.000000000',
#        '2011-08-31T00:00:00.000000000', '2011-09-30T00:00:00.000000000',
#        '2011-10-31T00:00:00.000000000', '2011-11-30T00:00:00.000000000',
#        '2011-12-31T00:00:00.000000000', '2012-01-31T00:00:00.000000000',
#        '2012-02-29T00:00:00.000000000', '2012-03-31T00:00:00.000000000',
#        '2012-04-30T00:00:00.000000000', '2012-05-31T00:00:00.000000000',
#        '2012-06-30T00:00:00.000000000', '2012-07-31T00:00:00.000000000',
#        '2012-08-31T00:00:00.000000000', '2012-09-30T00:00:00.000000000',
#        '2012-10-31T00:00:00.000000000', '2012-11-30T00:00:00.000000000',
#        '2012-12-31T00:00:00.000000000', '2013-01-31T00:00:00.000000000',
#        '2013-02-28T00:00:00.000000000', '2013-03-31T00:00:00.000000000',
#        '2013-04-30T00:00:00.000000000', '2013-05-31T00:00:00.000000000',
#        '2013-06-30T00:00:00.000000000', '2013-07-31T00:00:00.000000000',
#        '2013-08-31T00:00:00.000000000', '2013-09-30T00:00:00.000000000',
#        '2013-10-31T00:00:00.000000000', '2013-11-30T00:00:00.000000000',
#        '2013-12-31T00:00:00.000000000', '2014-01-31T00:00:00.000000000',
#        '2014-02-28T00:00:00.000000000', '2014-03-31T00:00:00.000000000',
#        '2014-04-30T00:00:00.000000000', '2014-05-31T00:00:00.000000000',
#        '2014-06-30T00:00:00.000000000', '2014-07-31T00:00:00.000000000',
#        '2014-08-31T00:00:00.000000000', '2014-09-30T00:00:00.000000000',
#        '2014-10-31T00:00:00.000000000', '2014-11-30T00:00:00.000000000',
#        '2014-12-31T00:00:00.000000000', '2015-01-31T00:00:00.000000000',
#        '2015-02-28T00:00:00.000000000', '2015-03-31T00:00:00.000000000',
#        '2015-04-30T00:00:00.000000000', '2015-05-31T00:00:00.000000000',
#        '2015-06-30T00:00:00.000000000', '2015-07-31T00:00:00.000000000',
#        '2015-08-31T00:00:00.000000000', '2015-09-30T00:00:00.000000000',
#        '2015-10-31T00:00:00.000000000', '2015-11-30T00:00:00.000000000',
#        '2015-12-31T00:00:00.000000000', '2016-01-31T00:00:00.000000000',
#        '2016-02-29T00:00:00.000000000', '2016-03-31T00:00:00.000000000',
#        '2016-04-30T00:00:00.000000000', '2016-05-31T00:00:00.000000000',
#        '2016-06-30T00:00:00.000000000', '2016-07-31T00:00:00.000000000',
#        '2016-08-31T00:00:00.000000000', '2016-09-30T00:00:00.000000000',
#        '2016-10-31T00:00:00.000000000', '2016-11-30T00:00:00.000000000',
#        '2016-12-31T00:00:00.000000000', '2017-01-31T00:00:00.000000000',
#        '2017-02-28T00:00:00.000000000', '2017-03-31T00:00:00.000000000',
#        '2017-04-30T00:00:00.000000000', '2017-05-31T00:00:00.000000000',
#        '2017-06-30T00:00:00.000000000', '2017-07-31T00:00:00.000000000',
#        '2017-08-31T00:00:00.000000000', '2017-09-30T00:00:00.000000000',
#        '2017-10-31T00:00:00.000000000', '2017-11-30T00:00:00.000000000',
#        '2017-12-31T00:00:00.000000000', '2018-01-31T00:00:00.000000000',
#        '2018-02-28T00:00:00.000000000', '2018-03-31T00:00:00.000000000',
#        '2018-04-30T00:00:00.000000000', '2018-05-31T00:00:00.000000000',
#        '2018-06-30T00:00:00.000000000', '2018-07-31T00:00:00.000000000',
#        '2018-08-31T00:00:00.000000000', '2018-09-30T00:00:00.000000000',
#        '2018-10-31T00:00:00.000000000', '2018-11-30T00:00:00.000000000',
#        '2018-12-31T00:00:00.000000000', '2019-01-31T00:00:00.000000000',
#        '2019-02-28T00:00:00.000000000', '2019-03-31T00:00:00.000000000',
#        '2019-04-30T00:00:00.000000000', '2019-05-31T00:00:00.000000000',
#        '2019-06-30T00:00:00.000000000', '2019-07-31T00:00:00.000000000',
#        '2019-08-31T00:00:00.000000000', '2019-09-30T00:00:00.000000000',
#        '2019-10-31T00:00:00.000000000', '2019-11-30T00:00:00.000000000',
#        '2019-12-31T00:00:00.000000000', '2020-01-31T00:00:00.000000000',
#        '2020-02-29T00:00:00.000000000', '2020-03-31T00:00:00.000000000',
#        '2020-04-30T00:00:00.000000000', '2020-05-31T00:00:00.000000000',
#        '2020-06-30T00:00:00.000000000', '2020-07-31T00:00:00.000000000',
#        '2020-08-31T00:00:00.000000000', '2020-09-30T00:00:00.000000000',
#        '2020-10-31T00:00:00.000000000', '2020-11-30T00:00:00.000000000',
#        '2020-12-31T00:00:00.000000000', '2021-01-31T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
dataset.date.shift(132, freq="MS").index.values
# Out:
# array(['1760-01-01T00:00:00.000000000', '1760-02-01T00:00:00.000000000',
#        '1760-03-01T00:00:00.000000000', ...,
#        '2031-11-01T00:00:00.000000000', '2031-12-01T00:00:00.000000000',
#        '2032-01-01T00:00:00.000000000'], dtype='datetime64[ns]')
