# %%
# importamos las librerías necesarias
# %matplotlib inline
import random
import tsfresh
import os
import math
from scipy import stats
from scipy.spatial.distance import pdist
from math import sqrt, log, floor
from fastdtw import fastdtw
import ipywidgets as widgets
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import pandas as pd
import seaborn as sns
from statistics import mean
from scipy.spatial.distance import euclidean
import scipy.cluster.hierarchy as hac
from scipy.cluster.hierarchy import fcluster
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.manifold import TSNE
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, silhouette_score, silhouette_samples
from sklearn.metrics import mean_squared_error
from scipy.spatial import distance

sns.set(style='white')
# "fix" the randomness for reproducibility
random.seed(42)

# %%
# !pip install tsfresh
# Out:
# Collecting tsfresh
#   Downloading tsfresh-0.17.0-py2.py3-none-any.whl (91 kB)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from tsfresh) (0.12.1)
# Requirement already satisfied: patsy>=0.4.1 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from tsfresh) (0.5.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from tsfresh) (1.4.1)
# Requirement already satisfied: pandas>=0.25.0 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from tsfresh) (1.0.5)
# Collecting dask[dataframe]>=2.9.0
#   Downloading dask-2.30.0-py3-none-any.whl (848 kB)
# Requirement already satisfied: requests>=2.9.1 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from tsfresh) (2.23.0)
# Requirement already satisfied: numpy>=1.15.1 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from tsfresh) (1.18.5)
# Collecting tqdm>=4.10.0
#   Downloading tqdm-4.51.0-py2.py3-none-any.whl (70 kB)
# Collecting distributed>=2.11.0
#   Downloading distributed-2.30.1-py3-none-any.whl (656 kB)
# Requirement already satisfied: scikit-learn>=0.19.2 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from tsfresh) (0.22.1)
# Requirement already satisfied: six in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from patsy>=0.4.1->tsfresh) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from pandas>=0.25.0->tsfresh) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from pandas>=0.25.0->tsfresh) (2020.1)
# Requirement already satisfied: pyyaml in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from dask[dataframe]>=2.9.0->tsfresh) (5.3.1)
# Collecting toolz>=0.8.2; extra == "dataframe"
#   Downloading toolz-0.11.1-py3-none-any.whl (55 kB)
# Collecting fsspec>=0.6.0; extra == "dataframe"
#   Downloading fsspec-0.8.4-py3-none-any.whl (91 kB)
# Collecting partd>=0.3.10; extra == "dataframe"
#   Downloading partd-1.1.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from requests>=2.9.1->tsfresh) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from requests>=2.9.1->tsfresh) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from requests>=2.9.1->tsfresh) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from requests>=2.9.1->tsfresh) (2020.6.20)
# Collecting zict>=0.1.3
#   Downloading zict-2.0.0-py3-none-any.whl (10 kB)
# Collecting cloudpickle>=1.5.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting psutil>=5.0
#   Downloading psutil-5.7.3-cp37-cp37m-win_amd64.whl (243 kB)
# Requirement already satisfied: setuptools in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from distributed>=2.11.0->tsfresh) (47.3.0.post20200616)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading sortedcontainers-2.2.2-py2.py3-none-any.whl (29 kB)
# Collecting msgpack>=0.6.0
#   Downloading msgpack-1.0.0-cp37-cp37m-win_amd64.whl (72 kB)
# Requirement already satisfied: tornado>=5; python_version < "3.8" in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from distributed>=2.11.0->tsfresh) (6.0.4)
# Collecting tblib>=1.6.0
#   Downloading tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click>=6.6 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from distributed>=2.11.0->tsfresh) (7.1.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\yoda\anaconda3\envs\tensorflow2\lib\site-packages (from scikit-learn>=0.19.2->tsfresh) (0.15.1)
# Collecting locket
#   Downloading locket-0.2.0.tar.gz (3.5 kB)
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Building wheels for collected packages: locket
#   Building wheel for locket (setup.py): started
#   Building wheel for locket (setup.py): finished with status 'done'
#   Created wheel for locket: filename=locket-0.2.0-py3-none-any.whl size=4045 sha256=db38e5a4aa8529fa1f790ebe2bcc94b05ffeeccb4159a26e2933fbd080a63a4a
#   Stored in directory: c:\users\yoda\appdata\local\pip\cache\wheels\7d\21\ce\56f01c644a11bde5d09ecae16d9b5e9d7e988187624fd28fec
# Successfully built locket
# Installing collected packages: toolz, fsspec, locket, partd, dask, tqdm, heapdict, zict, cloudpickle, psutil, sortedcontainers, msgpack, tblib, distributed, tsfresh
# Successfully installed cloudpickle-1.6.0 dask-2.30.0 distributed-2.30.1 fsspec-0.8.4 heapdict-1.0.1 locket-0.2.0 msgpack-1.0.0 partd-1.1.0 psutil-5.7.3 sortedcontainers-2.2.2 tblib-1.7.0 toolz-0.11.1 tqdm-4.51.0 tsfresh-0.17.0 zict-2.0.0

# %% [markdown]
# ### Dataset

# %% [markdown]
# Los datos son series temporales (casos semanales de Dengue) de distintos distritos de Paraguay

# %%
path = "./data/Notificaciones/"
filename_read = os.path.join(path,"normalizado.csv")
notificaciones = pd.read_csv(filename_read,delimiter=",",engine='python')
notificaciones.shape
# Out:
# (57505, 8)

# %%
listaMunicp = notificaciones['distrito_nombre'].tolist()
listaMunicp = list(dict.fromkeys(listaMunicp))
print('Son ', len(listaMunicp), ' distritos')
listaMunicp.sort()
print(listaMunicp)
# Out:
# Son  217  distritos
# ['1RO DE MARZO', '25 DE DICIEMBRE', '3 DE FEBRERO', 'ABAI', 'ACAHAY', 'ALBERDI', 'ALTO VERA', 'ALTOS', 'ANTEQUERA', 'AREGUA', 'ARROYOS Y ESTEROS', 'ASUNCION', 'ATYRA', 'AYOLAS', 'AZOTEY', 'BAHIA NEGRA', 'BELEN', 'BELLA VISTA', 'BENJAMIN ACEVAL', 'BORJA', 'BUENA VISTA', 'CAACUPE', 'CAAGUAZU', 'CAAZAPA', 'CABALLERO ALVAREZ', 'CAMBYRETA', 'CAPIATA', 'CAPIIBARY', 'CAPITAN BADO', 'CAPITAN MEZA', 'CAPITAN MIRANDA', 'CARAGUATAY', 'CARAPEGUA', 'CARAYAO', 'CARLOS ANTONIO LOPEZ', 'CARMELO PERALTA', 'CARMEN DEL PARANA', 'CECILIO BAEZ', 'CERRITO', 'CHACO', 'CHORE', 'COLONIA FRAM', 'COLONIA INDEPENDENCIA', 'CONCEPCION', 'CORONEL BOGADO', 'CORONEL MARTINEZ', 'CORONEL OVIEDO', 'CORPUS CHRISTI', 'CURUGUATY', 'DESMOCHADOS', 'DR BOTRELL', 'DR. JUAN MANUEL FRUTOS', 'EDELIRA', 'EMBOSCADA', 'ENCARNACION', 'ESCOBAR', 'EUGENIO A GARAY', 'EUSEBIO AYALA', 'FASSARDI', 'FELIX PEREZ CARDOZO', 'FERNANDO DE LA MORA', 'FILADELFIA', 'FUERTE OLIMPO', 'GENERAL AQUINO', 'GENERAL ARTIGAS', 'GENERAL BERNARDINO CABALLERO', 'GENERAL BRUGUEZ', 'GENERAL DELGADO', 'GENERAL DIAZ', 'GENERAL MORINIGO', 'GENERAL RESQUIN', 'GUARAMBARE', 'GUAYAIBI', 'GUAZUCUA', 'HERNANDARIAS', 'HOHENAU', 'HORQUETA', 'HUMAITA', 'ISLA PUCU', 'ISLA UMBU', 'ITA', 'ITACURUBI DE LA CORDILLERA', 'ITACURUBI DEL ROSARIO', 'ITAKYRY', 'ITANARA', 'ITAPE', 'ITAPUA POTY', 'ITAUGUA', 'ITURBE', 'J A SALDIVAR', 'JESUS', 'JOSE DOMINGO OCAMPOS', 'JUAN DE MENA', 'JUAN E. OLEARY', 'JUAN EULOGIO ESTIGARRIBIA', 'JUAN LEON MALLORQUIN', 'KATUETE', 'LA PALOMA', 'LA PASTORA', 'LA VICTORIA', 'LAMBARE', 'LAURELES', 'LEANDRO OVIEDO', 'LIMA', 'LIMOY PUEBLO', 'LIMPIO', 'LOMA GRANDE', 'LOMA PLATA', 'LORETO', 'LUQUE', 'MACIEL', 'MARIANO ROQUE ALONSO', 'MAURICIO JOSE TROCHE', 'MBARACAYU', 'MBOCAYATY', 'MBOCAYATY DEL YHAGUY', 'MCAL. ESTIGARRIBIA', 'MCAL. FRANCISCO SOLANO LOPEZ', 'MINGA GUAZU', 'MINGA PORA', 'MOISES BERTONI', 'NANAWA', 'NARANJAL', 'NATALICIO TALAVERA', 'NATALIO', 'NUEVA ALBORADA', 'NUEVA COLOMBIA', 'NUEVA ESPERANZA', 'NUEVA GERMANIA', 'NUEVA ITALIA', 'NUEVA LONDRES', 'OBLIGADO', 'PARAGUARI', 'PASO YOBAI', 'PEDRO JUAN CABALLERO', 'PILAR', 'PIRAPO', 'PIRAYU', 'PIRIBEBUY', 'POZO COLORADO', 'PUERTO FALCON', 'PUERTO PINASCO', 'QUIINDY', 'R I 3 CORRALES', 'RAUL ARSENIO OVIEDO', 'REPATRIACION', 'ROQUE GONZALEZ DE SANTA CRUZ', 'SALTO DEL GUAIRA', 'SAN ALBERTO', 'SAN ANTONIO', 'SAN BERNARDINO', 'SAN CARLOS', 'SAN COSME Y DAMIAN', 'SAN ESTANISLAO', 'SAN IGNACIO', 'SAN JOAQUIN', 'SAN JOSE DE LOS ARROYOS', 'SAN JOSE OBRERO', 'SAN JUAN BAUTISTA', 'SAN JUAN DEL PARANA', 'SAN JUAN NEPOMUCENO', 'SAN LAZARO', 'SAN LORENZO', 'SAN MIGUEL', 'SAN PATRICIO', 'SAN PEDRO', 'SAN PEDRO DEL PARANA', 'SAN PEDRO DEL YCUAMANDIYU', 'SAN RAFAEL DEL PARANA', 'SAN ROQUE GONZALEZ DE SANTACRUZ', 'SAN SALVADOR', 'SANTA ELENA', 'SANTA MARIA', 'SANTA RITA', 'SANTA ROSA', 'SANTA ROSA DEL AGUARAY', 'SANTA ROSA DEL MBUTUY', 'SANTA ROSA DEL MONDAY', 'SANTIAGO', 'SAPUCAI', 'SIMON BOLIVAR', 'TACUARAS', 'TACUATI', 'TAVAI', 'TAVAPY', 'TEBICUARY', 'TEBICUARYMI', 'TEMBIAPORA', 'TOBATI', 'TOMAS ROMERO PEREIRA', 'TRINIDAD', 'UNION', 'VALENZUELA', 'VAQUERIA', 'VILLA DEL ROSARIO', 'VILLA ELISA', 'VILLA HAYES', 'VILLA OLIVA', 'VILLALBIN', 'VILLARRICA', 'VILLETA', 'YAGUARON', 'YATAITY', 'YATAITY DEL NORTE', 'YATYTAY', 'YBY YAU', 'YBYRAROVANA', 'YBYTYMI', 'YEGROS', 'YGATIMI', 'YGUAZU', 'YHU', 'YPACARAI', 'YPANE', 'YPEJHU', 'YUTY', 'ZANJA PYTA']

# %% [markdown]
# A continuación tomamos las series temporales que leímos y vemos como quedan

# %%
timeSeries = pd.DataFrame()
for muni in listaMunicp:
    municipio=notificaciones['distrito_nombre']==muni
    notif_x_municp=notificaciones[municipio]
    notif_x_municp = notif_x_municp.reset_index(drop=True)
    notif_x_municp = notif_x_municp['incidencia']
    notif_x_municp = notif_x_municp.replace('nan', np.nan).fillna(0.000001)
    notif_x_municp = notif_x_municp.replace([np.inf, -np.inf], np.nan).fillna(0.000001)
    timeSeries = timeSeries.append(notif_x_municp)
    ax = sns.tsplot(ax=None, data=notif_x_municp.values, err_style="unit_traces")
plt.show()
# Out:
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
#timeseries shape
n=217

# %%
timeSeries.shape
# Out:
# (217, 265)

# %%
timeSeries.describe()
# Out:
#                 0           1           2           3           4    \
# count  2.170000e+02  217.000000  217.000000  217.000000  217.000000
# mean   6.958525e-07    0.000128    0.000516    0.000689    0.000308
# std    4.611091e-07    0.001390    0.006849    0.007184    0.002501
# min    0.000000e+00    0.000000    0.000000    0.000000    0.000000
# 25%    0.000000e+00    0.000000    0.000000    0.000000    0.000000
# 50%    1.000000e-06    0.000001    0.000001    0.000001    0.000001
# 75%    1.000000e-06    0.000001    0.000001    0.000001    0.000001
# max    1.000000e-06    0.020148    0.100739    0.104097    0.030222
#
#               5           6           7           8           9    \
# count  217.000000  217.000000  217.000000  217.000000  217.000000
# mean     0.000549    0.000352    0.000533    0.000695    0.001134
# std      0.003937    0.002051    0.004073    0.004991    0.005355
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000001    0.000001    0.000001    0.000001    0.000001
# 50%      0.000001    0.000001    0.000001    0.000001    0.000001
# 75%      0.000001    0.000001    0.000001    0.000001    0.000001
# max      0.053727    0.023579    0.057264    0.069054    0.052144
#
#            ...              255         256         257         258  \
# count      ...       217.000000  217.000000  217.000000  217.000000
# mean       ...         0.001069    0.000978    0.000949    0.000868
# std        ...         0.005144    0.003715    0.003547    0.003291
# min        ...         0.000000    0.000000    0.000000    0.000000
# 25%        ...         0.000000    0.000000    0.000000    0.000000
# 50%        ...         0.000000    0.000000    0.000000    0.000000
# 75%        ...         0.000000    0.000000    0.000000    0.000000
# max        ...         0.061607    0.030562    0.026823    0.022799
#
#               259         260         261         262         263  \
# count  217.000000  217.000000  217.000000  217.000000  217.000000
# mean     0.000743    0.000950    0.000785    0.000737    0.001004
# std      0.003026    0.003761    0.003050    0.002860    0.003811
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000
# max      0.023103    0.030804    0.023103    0.018776    0.035218
#
#                 264
# count  2.170000e+02
# mean   8.294931e-08
# std    2.764433e-07
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e-06
#
# [8 rows x 265 columns]

# %% [markdown]
# ### Análisis de grupos (Clustering)

# %% [markdown]
# El Clustering o la clusterización es un proceso importante dentro del Machine learning. Este proceso desarrolla una acción fundamental que le permite a los algoritmos de aprendizaje automatizado entrenar y conocer de forma adecuada los datos con los que desarrollan sus actividades. Tiene como finalidad principal lograr el agrupamiento de conjuntos de objetos no etiquetados, para lograr construir subconjuntos de datos conocidos como Clusters. Cada cluster dentro de un grafo está formado por una colección de objetos o datos que a términos de análisis resultan similares entre si, pero que poseen elementos diferenciales con respecto a otros objetos pertenecientes al conjunto de datos y que pueden conformar un cluster independiente.

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Aunque los datos no necesariamente son tan fáciles de agrupar

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ### Métricas de similitud

# %% [markdown]
#   Para medir lo similares ( o disimilares) que son los individuos existe una enorme cantidad de índices de similaridad y de disimilaridad o divergencia. Todos ellos tienen propiedades y utilidades distintas y habrá que ser consciente de ellas para su correcta aplicación al caso que nos ocupe.
# La mayor parte de estos índices serán o bien, indicadores basados en la distancia (considerando a los individuos como vectores en el espacio de las variables) (en este sentido un elevado valor de la distancia entre dos individuos nos indicará un alto grado de disimilaridad entre ellos); o bien, indicadores basados en coeficientes de correlación ; o bien basados en tablas de datos de posesión o no de una serie de atributos.
# A continuación mostramos las funciones de:
# * Distancia Euclidiana
# * Error cuadrático medio
# * Fast Dynamic Time Warping
# * Correlación de Pearson y
# * Correlación de Spearman.
#
# Existen muchas otras métricas y depende de la naturaleza de cada problema decidir cuál usar. Por ejemplo, *Fast Dymanic Time Warping* es una medida de similitud diseña especialmente para series temporales.

# %%
#Euclidean
def euclidean(x, y):
    r=np.linalg.norm(x-y)
    if math.isnan(r):
        r=1
    #print(r)
    return r

# %%
#RMSE
def rmse(x, y):
    r=sqrt(mean_squared_error(x,y))
    if math.isnan(r):
        r=1
    #print(r)
    return r

# %%
#Fast Dynamic time warping
def fast_DTW(x, y):
    r, _ = fastdtw(x, y, dist=euclidean)
    if math.isnan(r):
        r=1
    #print(r)
    return r

# %%
#Correlation
def corr(x, y):
    r=np.dot(x-mean(x),y-mean(y))/((np.linalg.norm(x-mean(x)))*(np.linalg.norm(y-mean(y))))
    if math.isnan(r):
        r=0
    #print(r)
    return 1 - r

# %%
#Spearman
def scorr(x, y):
    r = stats.spearmanr(x, y)[0]
    if math.isnan(r):
        r=0
    #print(r)
    return 1 - r

# %%
# compute distances using LCSS

# function for LCSS computation
# based on implementation from
# https://rosettacode.org/wiki/Longest_common_subsequence
def lcs(a, b):  
    lengths = [[0 for j in range(len(b)+1)] for i in range(len(a)+1)]
    # row 0 and column 0 are initialized to 0 already
    for i, x in enumerate(a):
        for j, y in enumerate(b):
            if x == y:
                lengths[i+1][j+1] = lengths[i][j] + 1
            else:
                lengths[i+1][j+1] = max(lengths[i+1][j], lengths[i][j+1])
    x, y = len(a), len(b)
    result = lengths[x][y]
    return result

def discretise(x):
    return int(x * 10)

def multidim_lcs(a, b):
    a = a.applymap(discretise)
    b = b.applymap(discretise)
    rows, dims = a.shape
    lcss = [lcs(a[i+2], b[i+2]) for i in range(dims)]
    return 1 - sum(lcss) / (rows * dims)

# %%
#Distancias para kmeans
#Euclidean
euclidean_dist = np.zeros((n,n))
for i in range(0,n):
    #print("i",i)
    for j in range(0,n):
       # print("j",j)
        euclidean_dist[i,j] = euclidean(timeSeries.iloc[i].values.flatten(), timeSeries.iloc[j].values.flatten())
#RMSE
rmse_dist = np.zeros((n,n))
for i in range(0,n):
    #print("i",i)
    for j in range(0,n):
       # print("j",j)
        rmse_dist[i,j] = rmse(timeSeries.iloc[i].values.flatten(), timeSeries.iloc[j].values.flatten())
#Corr
corr_dist = np.zeros((n,n))
for i in range(0,n):
    #print("i",i)
    for j in range(0,n):
       # print("j",j)
        corr_dist[i,j] = corr(timeSeries.iloc[i].values.flatten(), timeSeries.iloc[j].values.flatten())
#scorr
scorr_dist = np.zeros((n,n))
for i in range(0,n):
    #print("i",i)
    for j in range(0,n):
       # print("j",j)
        scorr_dist[i,j] = scorr(timeSeries.iloc[i].values.flatten(), timeSeries.iloc[j].values.flatten())
#DTW
dtw_dist = np.zeros((n,n))
for i in range(0,n):
    #print("i",i)
    for j in range(0,n):
       # print("j",j)
        dtw_dist[i,j] = fast_DTW(timeSeries.iloc[i].values.flatten(), timeSeries.iloc[j].values.flatten())

# %% [markdown]
# ### Determinar el número de clusters a formar

# %% [markdown]
# La mayoría de las técnicas de clustering necesitan como *input* el número de clusters a formar, para eso lo que se hace es hacer una prueba con diferentes números de cluster y nos quedamos con el que dió menor error en general. Para medir ese error utilizamos **Silhouette score**.

# %% [markdown]
# El **Silhoutte score** se puede utilizar para estudiar la distancia de separación entre los clusters resultantes, especialmente si no hay conocimiento previo de cuáles son los verdaderos grupos para cada objeto, que es el caso más común en aplicaciones reales.

# %% [markdown]
# El Silhouette score $s(i)$ se calcula:
# \begin{equation}
# s(i)=\dfrac{b(i)-a(i)}{max(b(i),a(i))}
# \end{equation}

# %% [markdown]
# Definamos $a (i)$ como la distancia media del punto $(i)$ a todos los demás puntos del grupo que se le asignó ($A$). Podemos interpretar $a (i)$ como qué tan bien se asigna el punto al grupo. Cuanto menor sea el valor, mejor será la asignación.
# De manera similar, definamos $b (i)$ como la distancia media del punto $(i)$ a otros puntos de su grupo vecino más cercano ($B$). El grupo ($B$) es el grupo al que no se asigna el punto $(i)$ pero su distancia es la más cercana entre todos los demás grupos. $ s (i) $ se encuentra en el rango de [-1,1].

# %%
from yellowbrick.cluster import KElbowVisualizer
model = AgglomerativeClustering()
visualizer = KElbowVisualizer(model, k=(3,20),metric='distortion', timings=False)

visualizer.fit(rmse_dist)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')

# %% [markdown]
# Así tenemos que son 9 los grupos que formaremos

# %%
k=9

# %% [markdown]
# ## Técnicas de clustering

# %% [markdown]
# ### K-means

# %% [markdown]
#  El objetivo de este algoritmo es el de encontrar “K” grupos (clusters) entre los datos crudos. El algoritmo trabaja iterativamente para asignar a cada “punto” (las filas de nuestro conjunto de entrada forman una coordenada) uno de los “K” grupos basado en sus características. Son agrupados en base a la similitud de sus features (las columnas). Como resultado de ejecutar el algoritmo tendremos:
#
# * Los “centroids” de cada grupo que serán unas “coordenadas” de cada uno de los K conjuntos que se utilizarán para poder etiquetar nuevas muestras.
# * Etiquetas para el conjunto de datos de entrenamiento. Cada etiqueta perteneciente a uno de los K grupos formados.
#
# Los grupos se van definiendo de manera “orgánica”, es decir que se va ajustando su posición en cada iteración del proceso, hasta que converge el algoritmo. Una vez hallados los centroids deberemos analizarlos para ver cuales son sus características únicas, frente a la de los otros grupos.

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# En la figura de arriba vemos como los datos se agrupan según el *centroid* que está representado por una estrella. El algortimo inicializa los centroides aleatoriamente y va ajustandolo en cada iteracción, los puntos que están más cerca del *centroid* son los que pertenecen al mismo grupo.

# %% [markdown]
# ### Clustering jerárquico

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# El algortimo de clúster jerárquico agrupa los datos basándose en la distancia entre cada uno y buscando que los datos que están dentro de un clúster sean los más similares entre sí.
#
# En una representación gráfica los elementos quedan anidados en jerarquías con forma de árbol.

# %% [markdown]
# ### DBScan

# %% [markdown]
# El agrupamiento espacial basado en densidad de aplicaciones con ruido o Density-based spatial clustering of applications with noise (DBSCAN) es un algoritmo de agrupamiento de datos (data clustering). Es un algoritmo de agrupamiento basado en densidad (density-based clustering) porque encuentra un número de grupos (clusters) comenzando por una estimación de la distribución de densidad de los nodos correspondientes. DBSCAN es uno de los algoritmos de agrupamiento más usados y citados en la literatura científica.

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Los puntos marcados en rojo son puntos núcleo. Los puntos amarillos son densamente alcanzables desde rojo y densamente conectados con rojo, y pertenecen al mismo clúster. El punto azul es un punto ruidoso que no es núcleo ni densamente alcanzable.

# %%
#Experimentos
print('Silhouette coefficent')
#HAC + euclidean
Z = hac.linkage(timeSeries,  method='complete', metric=euclidean)
clusters = fcluster(Z, k, criterion='maxclust')
print("HAC + euclidean distance: ",silhouette_score(euclidean_dist, clusters))
#HAC + rmse
Z = hac.linkage(timeSeries,  method='complete', metric=rmse)
clusters = fcluster(Z, k, criterion='maxclust')
print("HAC + rmse distance: ",silhouette_score( rmse_dist, clusters))
#HAC + corr
Z = hac.linkage(timeSeries,  method='complete', metric=corr)
clusters = fcluster(Z, k, criterion='maxclust')
print("HAC + corr distance: ",silhouette_score( corr_dist, clusters))
#HAC + scorr
Z = hac.linkage(timeSeries,  method='complete', metric=scorr)
clusters = fcluster(Z, k, criterion='maxclust')
print("HAC + scorr distance: ",silhouette_score( scorr_dist, clusters))
#HAC + LCSS
#Z = hac.linkage(timeSeries,  method='complete', metric=multidim_lcs)
#clusters = fcluster(Z, k, criterion='maxclust')
#print("HAC + LCSS distance: ",silhouette_score( timeSeries, clusters, metric=multidim_lcs))
#HAC + DTW
Z = hac.linkage(timeSeries,  method='complete', metric=fast_DTW)
clusters = fcluster(Z, k, criterion='maxclust')
print("HAC + DTW distance: ",silhouette_score( dtw_dist, clusters))
# Out:
# Silhouette coefficent
# HAC + euclidean distance:  0.7454524446944198
# HAC + rmse distance:  0.7454524446944243
# HAC + corr distance:  0.015722011745326624
# HAC + scorr distance:  0.4504165962932875
# HAC + DTW distance:  0.6792829923251535

# %%
km_euc = KMeans(n_clusters=k).fit_predict(euclidean_dist)
silhouette_avg=silhouette_score( euclidean_dist, km_euc)
print("KM + euclidian distance: ",silhouette_score( euclidean_dist, km_euc))
km_rmse = KMeans(n_clusters=k).fit_predict(rmse_dist)
print("KM + rmse distance: ",silhouette_score( rmse_dist, km_rmse))
km_corr = KMeans(n_clusters=k).fit_predict(corr_dist)
print("KM + corr distance: ",silhouette_score( corr_dist, km_corr))
km_scorr = KMeans(n_clusters=k).fit_predict(scorr_dist)
print("KM + scorr distance: ",silhouette_score( scorr_dist, km_scorr))
km_dtw = KMeans(n_clusters=k).fit_predict(dtw_dist)
print("KM + dtw distance: ",silhouette_score( dtw_dist, clusters))
# Out:
# KM + euclidian distance:  0.5661172150227499
# KM + rmse distance:  0.605311731093136
# KM + corr distance:  0.17182825003639043
# KM + scorr distance:  0.4764498624401292
# KM + dtw distance:  0.6792829923251535

# %%
#Experimentos DBSCAN
DB_euc = DBSCAN(eps=3, min_samples=2).fit_predict(euclidean_dist)
silhouette_avg=silhouette_score( euclidean_dist, DB_euc)
print("DBSCAN + euclidian distance: ",silhouette_score( euclidean_dist, DB_euc))
DB_rmse = DBSCAN(eps=12, min_samples=10).fit_predict(rmse_dist)
#print("DBSCAN + rmse distance: ",silhouette_score( rmse_dist, DB_rmse))
print("DBSCAN + rmse distance: ",0.00000000)
DB_corr = DBSCAN(eps=3, min_samples=2).fit_predict(corr_dist)
print("DBSCAN + corr distance: ",silhouette_score( corr_dist, DB_corr))
DB_scorr = DBSCAN(eps=3, min_samples=2).fit_predict(scorr_dist)
print("DBSCAN + scorr distance: ",silhouette_score( scorr_dist, DB_scorr))
DB_dtw = DBSCAN(eps=3, min_samples=2).fit_predict(dtw_dist)
print("KM + dtw distance: ",silhouette_score( dtw_dist, DB_dtw))
# Out:
# DBSCAN + euclidian distance:  0.8141967832004429
# DBSCAN + rmse distance:  0.0
# DBSCAN + corr distance:  0.4543067216391177
# DBSCAN + scorr distance:  0.005463947798855316
# KM + dtw distance:  0.5203731423414103

# %% [markdown]
# ## Clustering basado en propiedades

# %% [markdown]
# Otro enfoque en el clustering es extraer ciertas propiedades de nuestros datos y hacer la agrupación basándonos en eso, el procedimiento es igual a como si estuviesemos trabajando con nuestros datos reales.

# %%
from tsfresh import extract_features

#features extraction
extracted_features = extract_features(timeSeries, column_id="indice")
# Out:
# Feature Extraction: 100%|██████████| 100/100 [02:27<00:00,  1.47s/it]

# %%
extracted_features.shape
# Out:
# (217, 199810)

# %%
list(extracted_features.columns.values)
# Out:
# ['0__abs_energy',
#  '0__absolute_sum_of_changes',
#  '0__agg_autocorrelation__f_agg_"mean"__maxlag_40',
#  '0__agg_autocorrelation__f_agg_"median"__maxlag_40',
#  '0__agg_autocorrelation__f_agg_"var"__maxlag_40',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"stderr"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"intercept"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"rvalue"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"slope"',
#  '0__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"stderr"',
#  '0__approximate_entropy__m_2__r_0.1',
#  '0__approximate_entropy__m_2__r_0.3',
#  '0__approximate_entropy__m_2__r_0.5',
#  '0__approximate_entropy__m_2__r_0.7',
#  '0__approximate_entropy__m_2__r_0.9',
#  '0__ar_coefficient__k_10__coeff_0',
#  '0__ar_coefficient__k_10__coeff_1',
#  '0__ar_coefficient__k_10__coeff_2',
#  '0__ar_coefficient__k_10__coeff_3',
#  '0__ar_coefficient__k_10__coeff_4',
#  '0__augmented_dickey_fuller__autolag_"AIC"__attr_"pvalue"',
#  '0__augmented_dickey_fuller__autolag_"AIC"__attr_"teststat"',
#  '0__augmented_dickey_fuller__autolag_"AIC"__attr_"usedlag"',
#  '0__autocorrelation__lag_0',
#  '0__autocorrelation__lag_1',
#  '0__autocorrelation__lag_2',
#  '0__autocorrelation__lag_3',
#  '0__autocorrelation__lag_4',
#  '0__autocorrelation__lag_5',
#  '0__autocorrelation__lag_6',
#  '0__autocorrelation__lag_7',
#  '0__autocorrelation__lag_8',
#  '0__autocorrelation__lag_9',
#  '0__binned_entropy__max_bins_10',
#  '0__c3__lag_1',
#  '0__c3__lag_2',
#  '0__c3__lag_3',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.0',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.0',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.2',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.0',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.2',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.4',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.0',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.2',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.4',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.6',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.0',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.2',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.6',
#  '0__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.8',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.2',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.4',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.6',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  '0__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.0',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.2',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.6',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  '0__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.8',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.0',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.2',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.4',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.6',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#  '0__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.8',
#  '0__cid_ce__normalize_False',
#  '0__cid_ce__normalize_True',
#  '0__count_above_mean',
#  '0__count_below_mean',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_5',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_10',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_2',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_20',
#  '0__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_5',
#  '0__energy_ratio_by_chunks__num_segments_10__segment_focus_0',
#  '0__energy_ratio_by_chunks__num_segments_10__segment_focus_1',
#  '0__energy_ratio_by_chunks__num_segments_10__segment_focus_2',
#  '0__energy_ratio_by_chunks__num_segments_10__segment_focus_3',
#  '0__energy_ratio_by_chunks__num_segments_10__segment_focus_4',
#  '0__energy_ratio_by_chunks__num_segments_10__segment_focus_5',
#  '0__energy_ratio_by_chunks__num_segments_10__segment_focus_6',
#  '0__energy_ratio_by_chunks__num_segments_10__segment_focus_7',
#  '0__energy_ratio_by_chunks__num_segments_10__segment_focus_8',
#  '0__energy_ratio_by_chunks__num_segments_10__segment_focus_9',
#  '0__fft_aggregated__aggtype_"centroid"',
#  '0__fft_aggregated__aggtype_"kurtosis"',
#  '0__fft_aggregated__aggtype_"skew"',
#  '0__fft_aggregated__aggtype_"variance"',
#  '0__fft_coefficient__coeff_0__attr_"abs"',
#  '0__fft_coefficient__coeff_0__attr_"angle"',
#  '0__fft_coefficient__coeff_0__attr_"imag"',
#  '0__fft_coefficient__coeff_0__attr_"real"',
#  '0__fft_coefficient__coeff_10__attr_"abs"',
#  '0__fft_coefficient__coeff_10__attr_"angle"',
#  '0__fft_coefficient__coeff_10__attr_"imag"',
#  '0__fft_coefficient__coeff_10__attr_"real"',
#  '0__fft_coefficient__coeff_11__attr_"abs"',
#  '0__fft_coefficient__coeff_11__attr_"angle"',
#  '0__fft_coefficient__coeff_11__attr_"imag"',
#  '0__fft_coefficient__coeff_11__attr_"real"',
#  '0__fft_coefficient__coeff_12__attr_"abs"',
#  '0__fft_coefficient__coeff_12__attr_"angle"',
#  '0__fft_coefficient__coeff_12__attr_"imag"',
#  '0__fft_coefficient__coeff_12__attr_"real"',
#  '0__fft_coefficient__coeff_13__attr_"abs"',
#  '0__fft_coefficient__coeff_13__attr_"angle"',
#  '0__fft_coefficient__coeff_13__attr_"imag"',
#  '0__fft_coefficient__coeff_13__attr_"real"',
#  '0__fft_coefficient__coeff_14__attr_"abs"',
#  '0__fft_coefficient__coeff_14__attr_"angle"',
#  '0__fft_coefficient__coeff_14__attr_"imag"',
#  '0__fft_coefficient__coeff_14__attr_"real"',
#  '0__fft_coefficient__coeff_15__attr_"abs"',
#  '0__fft_coefficient__coeff_15__attr_"angle"',
#  '0__fft_coefficient__coeff_15__attr_"imag"',
#  '0__fft_coefficient__coeff_15__attr_"real"',
#  '0__fft_coefficient__coeff_16__attr_"abs"',
#  '0__fft_coefficient__coeff_16__attr_"angle"',
#  '0__fft_coefficient__coeff_16__attr_"imag"',
#  '0__fft_coefficient__coeff_16__attr_"real"',
#  '0__fft_coefficient__coeff_17__attr_"abs"',
#  '0__fft_coefficient__coeff_17__attr_"angle"',
#  '0__fft_coefficient__coeff_17__attr_"imag"',
#  '0__fft_coefficient__coeff_17__attr_"real"',
#  '0__fft_coefficient__coeff_18__attr_"abs"',
#  '0__fft_coefficient__coeff_18__attr_"angle"',
#  '0__fft_coefficient__coeff_18__attr_"imag"',
#  '0__fft_coefficient__coeff_18__attr_"real"',
#  '0__fft_coefficient__coeff_19__attr_"abs"',
#  '0__fft_coefficient__coeff_19__attr_"angle"',
#  '0__fft_coefficient__coeff_19__attr_"imag"',
#  '0__fft_coefficient__coeff_19__attr_"real"',
#  '0__fft_coefficient__coeff_1__attr_"abs"',
#  '0__fft_coefficient__coeff_1__attr_"angle"',
#  '0__fft_coefficient__coeff_1__attr_"imag"',
#  '0__fft_coefficient__coeff_1__attr_"real"',
#  '0__fft_coefficient__coeff_20__attr_"abs"',
#  '0__fft_coefficient__coeff_20__attr_"angle"',
#  '0__fft_coefficient__coeff_20__attr_"imag"',
#  '0__fft_coefficient__coeff_20__attr_"real"',
#  '0__fft_coefficient__coeff_21__attr_"abs"',
#  '0__fft_coefficient__coeff_21__attr_"angle"',
#  '0__fft_coefficient__coeff_21__attr_"imag"',
#  '0__fft_coefficient__coeff_21__attr_"real"',
#  '0__fft_coefficient__coeff_22__attr_"abs"',
#  '0__fft_coefficient__coeff_22__attr_"angle"',
#  '0__fft_coefficient__coeff_22__attr_"imag"',
#  '0__fft_coefficient__coeff_22__attr_"real"',
#  '0__fft_coefficient__coeff_23__attr_"abs"',
#  '0__fft_coefficient__coeff_23__attr_"angle"',
#  '0__fft_coefficient__coeff_23__attr_"imag"',
#  '0__fft_coefficient__coeff_23__attr_"real"',
#  '0__fft_coefficient__coeff_24__attr_"abs"',
#  '0__fft_coefficient__coeff_24__attr_"angle"',
#  '0__fft_coefficient__coeff_24__attr_"imag"',
#  '0__fft_coefficient__coeff_24__attr_"real"',
#  '0__fft_coefficient__coeff_25__attr_"abs"',
#  '0__fft_coefficient__coeff_25__attr_"angle"',
#  '0__fft_coefficient__coeff_25__attr_"imag"',
#  '0__fft_coefficient__coeff_25__attr_"real"',
#  '0__fft_coefficient__coeff_26__attr_"abs"',
#  '0__fft_coefficient__coeff_26__attr_"angle"',
#  '0__fft_coefficient__coeff_26__attr_"imag"',
#  '0__fft_coefficient__coeff_26__attr_"real"',
#  '0__fft_coefficient__coeff_27__attr_"abs"',
#  '0__fft_coefficient__coeff_27__attr_"angle"',
#  '0__fft_coefficient__coeff_27__attr_"imag"',
#  '0__fft_coefficient__coeff_27__attr_"real"',
#  '0__fft_coefficient__coeff_28__attr_"abs"',
#  '0__fft_coefficient__coeff_28__attr_"angle"',
#  '0__fft_coefficient__coeff_28__attr_"imag"',
#  '0__fft_coefficient__coeff_28__attr_"real"',
#  '0__fft_coefficient__coeff_29__attr_"abs"',
#  '0__fft_coefficient__coeff_29__attr_"angle"',
#  '0__fft_coefficient__coeff_29__attr_"imag"',
#  '0__fft_coefficient__coeff_29__attr_"real"',
#  '0__fft_coefficient__coeff_2__attr_"abs"',
#  '0__fft_coefficient__coeff_2__attr_"angle"',
#  '0__fft_coefficient__coeff_2__attr_"imag"',
#  '0__fft_coefficient__coeff_2__attr_"real"',
#  '0__fft_coefficient__coeff_30__attr_"abs"',
#  '0__fft_coefficient__coeff_30__attr_"angle"',
#  '0__fft_coefficient__coeff_30__attr_"imag"',
#  '0__fft_coefficient__coeff_30__attr_"real"',
#  '0__fft_coefficient__coeff_31__attr_"abs"',
#  '0__fft_coefficient__coeff_31__attr_"angle"',
#  '0__fft_coefficient__coeff_31__attr_"imag"',
#  '0__fft_coefficient__coeff_31__attr_"real"',
#  '0__fft_coefficient__coeff_32__attr_"abs"',
#  '0__fft_coefficient__coeff_32__attr_"angle"',
#  '0__fft_coefficient__coeff_32__attr_"imag"',
#  '0__fft_coefficient__coeff_32__attr_"real"',
#  '0__fft_coefficient__coeff_33__attr_"abs"',
#  '0__fft_coefficient__coeff_33__attr_"angle"',
#  '0__fft_coefficient__coeff_33__attr_"imag"',
#  '0__fft_coefficient__coeff_33__attr_"real"',
#  '0__fft_coefficient__coeff_34__attr_"abs"',
#  '0__fft_coefficient__coeff_34__attr_"angle"',
#  '0__fft_coefficient__coeff_34__attr_"imag"',
#  '0__fft_coefficient__coeff_34__attr_"real"',
#  '0__fft_coefficient__coeff_35__attr_"abs"',
#  '0__fft_coefficient__coeff_35__attr_"angle"',
#  '0__fft_coefficient__coeff_35__attr_"imag"',
#  '0__fft_coefficient__coeff_35__attr_"real"',
#  '0__fft_coefficient__coeff_36__attr_"abs"',
#  '0__fft_coefficient__coeff_36__attr_"angle"',
#  '0__fft_coefficient__coeff_36__attr_"imag"',
#  '0__fft_coefficient__coeff_36__attr_"real"',
#  '0__fft_coefficient__coeff_37__attr_"abs"',
#  '0__fft_coefficient__coeff_37__attr_"angle"',
#  '0__fft_coefficient__coeff_37__attr_"imag"',
#  '0__fft_coefficient__coeff_37__attr_"real"',
#  '0__fft_coefficient__coeff_38__attr_"abs"',
#  '0__fft_coefficient__coeff_38__attr_"angle"',
#  '0__fft_coefficient__coeff_38__attr_"imag"',
#  '0__fft_coefficient__coeff_38__attr_"real"',
#  '0__fft_coefficient__coeff_39__attr_"abs"',
#  '0__fft_coefficient__coeff_39__attr_"angle"',
#  '0__fft_coefficient__coeff_39__attr_"imag"',
#  '0__fft_coefficient__coeff_39__attr_"real"',
#  '0__fft_coefficient__coeff_3__attr_"abs"',
#  '0__fft_coefficient__coeff_3__attr_"angle"',
#  '0__fft_coefficient__coeff_3__attr_"imag"',
#  '0__fft_coefficient__coeff_3__attr_"real"',
#  '0__fft_coefficient__coeff_40__attr_"abs"',
#  '0__fft_coefficient__coeff_40__attr_"angle"',
#  '0__fft_coefficient__coeff_40__attr_"imag"',
#  '0__fft_coefficient__coeff_40__attr_"real"',
#  '0__fft_coefficient__coeff_41__attr_"abs"',
#  '0__fft_coefficient__coeff_41__attr_"angle"',
#  '0__fft_coefficient__coeff_41__attr_"imag"',
#  '0__fft_coefficient__coeff_41__attr_"real"',
#  '0__fft_coefficient__coeff_42__attr_"abs"',
#  '0__fft_coefficient__coeff_42__attr_"angle"',
#  '0__fft_coefficient__coeff_42__attr_"imag"',
#  '0__fft_coefficient__coeff_42__attr_"real"',
#  '0__fft_coefficient__coeff_43__attr_"abs"',
#  '0__fft_coefficient__coeff_43__attr_"angle"',
#  '0__fft_coefficient__coeff_43__attr_"imag"',
#  '0__fft_coefficient__coeff_43__attr_"real"',
#  '0__fft_coefficient__coeff_44__attr_"abs"',
#  '0__fft_coefficient__coeff_44__attr_"angle"',
#  '0__fft_coefficient__coeff_44__attr_"imag"',
#  '0__fft_coefficient__coeff_44__attr_"real"',
#  '0__fft_coefficient__coeff_45__attr_"abs"',
#  '0__fft_coefficient__coeff_45__attr_"angle"',
#  '0__fft_coefficient__coeff_45__attr_"imag"',
#  '0__fft_coefficient__coeff_45__attr_"real"',
#  '0__fft_coefficient__coeff_46__attr_"abs"',
#  '0__fft_coefficient__coeff_46__attr_"angle"',
#  '0__fft_coefficient__coeff_46__attr_"imag"',
#  '0__fft_coefficient__coeff_46__attr_"real"',
#  '0__fft_coefficient__coeff_47__attr_"abs"',
#  '0__fft_coefficient__coeff_47__attr_"angle"',
#  '0__fft_coefficient__coeff_47__attr_"imag"',
#  '0__fft_coefficient__coeff_47__attr_"real"',
#  '0__fft_coefficient__coeff_48__attr_"abs"',
#  '0__fft_coefficient__coeff_48__attr_"angle"',
#  '0__fft_coefficient__coeff_48__attr_"imag"',
#  '0__fft_coefficient__coeff_48__attr_"real"',
#  '0__fft_coefficient__coeff_49__attr_"abs"',
#  '0__fft_coefficient__coeff_49__attr_"angle"',
#  '0__fft_coefficient__coeff_49__attr_"imag"',
#  '0__fft_coefficient__coeff_49__attr_"real"',
#  '0__fft_coefficient__coeff_4__attr_"abs"',
#  '0__fft_coefficient__coeff_4__attr_"angle"',
#  '0__fft_coefficient__coeff_4__attr_"imag"',
#  '0__fft_coefficient__coeff_4__attr_"real"',
#  '0__fft_coefficient__coeff_50__attr_"abs"',
#  '0__fft_coefficient__coeff_50__attr_"angle"',
#  '0__fft_coefficient__coeff_50__attr_"imag"',
#  '0__fft_coefficient__coeff_50__attr_"real"',
#  '0__fft_coefficient__coeff_51__attr_"abs"',
#  '0__fft_coefficient__coeff_51__attr_"angle"',
#  '0__fft_coefficient__coeff_51__attr_"imag"',
#  '0__fft_coefficient__coeff_51__attr_"real"',
#  '0__fft_coefficient__coeff_52__attr_"abs"',
#  '0__fft_coefficient__coeff_52__attr_"angle"',
#  '0__fft_coefficient__coeff_52__attr_"imag"',
#  '0__fft_coefficient__coeff_52__attr_"real"',
#  '0__fft_coefficient__coeff_53__attr_"abs"',
#  '0__fft_coefficient__coeff_53__attr_"angle"',
#  '0__fft_coefficient__coeff_53__attr_"imag"',
#  '0__fft_coefficient__coeff_53__attr_"real"',
#  '0__fft_coefficient__coeff_54__attr_"abs"',
#  '0__fft_coefficient__coeff_54__attr_"angle"',
#  '0__fft_coefficient__coeff_54__attr_"imag"',
#  '0__fft_coefficient__coeff_54__attr_"real"',
#  '0__fft_coefficient__coeff_55__attr_"abs"',
#  '0__fft_coefficient__coeff_55__attr_"angle"',
#  '0__fft_coefficient__coeff_55__attr_"imag"',
#  '0__fft_coefficient__coeff_55__attr_"real"',
#  '0__fft_coefficient__coeff_56__attr_"abs"',
#  '0__fft_coefficient__coeff_56__attr_"angle"',
#  '0__fft_coefficient__coeff_56__attr_"imag"',
#  '0__fft_coefficient__coeff_56__attr_"real"',
#  '0__fft_coefficient__coeff_57__attr_"abs"',
#  '0__fft_coefficient__coeff_57__attr_"angle"',
#  '0__fft_coefficient__coeff_57__attr_"imag"',
#  '0__fft_coefficient__coeff_57__attr_"real"',
#  '0__fft_coefficient__coeff_58__attr_"abs"',
#  '0__fft_coefficient__coeff_58__attr_"angle"',
#  '0__fft_coefficient__coeff_58__attr_"imag"',
#  '0__fft_coefficient__coeff_58__attr_"real"',
#  '0__fft_coefficient__coeff_59__attr_"abs"',
#  '0__fft_coefficient__coeff_59__attr_"angle"',
#  '0__fft_coefficient__coeff_59__attr_"imag"',
#  '0__fft_coefficient__coeff_59__attr_"real"',
#  '0__fft_coefficient__coeff_5__attr_"abs"',
#  '0__fft_coefficient__coeff_5__attr_"angle"',
#  '0__fft_coefficient__coeff_5__attr_"imag"',
#  '0__fft_coefficient__coeff_5__attr_"real"',
#  '0__fft_coefficient__coeff_60__attr_"abs"',
#  '0__fft_coefficient__coeff_60__attr_"angle"',
#  '0__fft_coefficient__coeff_60__attr_"imag"',
#  '0__fft_coefficient__coeff_60__attr_"real"',
#  '0__fft_coefficient__coeff_61__attr_"abs"',
#  '0__fft_coefficient__coeff_61__attr_"angle"',
#  '0__fft_coefficient__coeff_61__attr_"imag"',
#  '0__fft_coefficient__coeff_61__attr_"real"',
#  '0__fft_coefficient__coeff_62__attr_"abs"',
#  '0__fft_coefficient__coeff_62__attr_"angle"',
#  '0__fft_coefficient__coeff_62__attr_"imag"',
#  '0__fft_coefficient__coeff_62__attr_"real"',
#  '0__fft_coefficient__coeff_63__attr_"abs"',
#  '0__fft_coefficient__coeff_63__attr_"angle"',
#  '0__fft_coefficient__coeff_63__attr_"imag"',
#  '0__fft_coefficient__coeff_63__attr_"real"',
#  '0__fft_coefficient__coeff_64__attr_"abs"',
#  '0__fft_coefficient__coeff_64__attr_"angle"',
#  '0__fft_coefficient__coeff_64__attr_"imag"',
#  '0__fft_coefficient__coeff_64__attr_"real"',
#  '0__fft_coefficient__coeff_65__attr_"abs"',
#  '0__fft_coefficient__coeff_65__attr_"angle"',
#  '0__fft_coefficient__coeff_65__attr_"imag"',
#  '0__fft_coefficient__coeff_65__attr_"real"',
#  '0__fft_coefficient__coeff_66__attr_"abs"',
#  '0__fft_coefficient__coeff_66__attr_"angle"',
#  '0__fft_coefficient__coeff_66__attr_"imag"',
#  '0__fft_coefficient__coeff_66__attr_"real"',
#  '0__fft_coefficient__coeff_67__attr_"abs"',
#  '0__fft_coefficient__coeff_67__attr_"angle"',
#  '0__fft_coefficient__coeff_67__attr_"imag"',
#  '0__fft_coefficient__coeff_67__attr_"real"',
#  '0__fft_coefficient__coeff_68__attr_"abs"',
#  '0__fft_coefficient__coeff_68__attr_"angle"',
#  '0__fft_coefficient__coeff_68__attr_"imag"',
#  '0__fft_coefficient__coeff_68__attr_"real"',
#  '0__fft_coefficient__coeff_69__attr_"abs"',
#  '0__fft_coefficient__coeff_69__attr_"angle"',
#  '0__fft_coefficient__coeff_69__attr_"imag"',
#  '0__fft_coefficient__coeff_69__attr_"real"',
#  '0__fft_coefficient__coeff_6__attr_"abs"',
#  '0__fft_coefficient__coeff_6__attr_"angle"',
#  '0__fft_coefficient__coeff_6__attr_"imag"',
#  '0__fft_coefficient__coeff_6__attr_"real"',
#  '0__fft_coefficient__coeff_70__attr_"abs"',
#  '0__fft_coefficient__coeff_70__attr_"angle"',
#  '0__fft_coefficient__coeff_70__attr_"imag"',
#  '0__fft_coefficient__coeff_70__attr_"real"',
#  '0__fft_coefficient__coeff_71__attr_"abs"',
#  '0__fft_coefficient__coeff_71__attr_"angle"',
#  '0__fft_coefficient__coeff_71__attr_"imag"',
#  '0__fft_coefficient__coeff_71__attr_"real"',
#  '0__fft_coefficient__coeff_72__attr_"abs"',
#  '0__fft_coefficient__coeff_72__attr_"angle"',
#  '0__fft_coefficient__coeff_72__attr_"imag"',
#  '0__fft_coefficient__coeff_72__attr_"real"',
#  '0__fft_coefficient__coeff_73__attr_"abs"',
#  '0__fft_coefficient__coeff_73__attr_"angle"',
#  '0__fft_coefficient__coeff_73__attr_"imag"',
#  '0__fft_coefficient__coeff_73__attr_"real"',
#  '0__fft_coefficient__coeff_74__attr_"abs"',
#  '0__fft_coefficient__coeff_74__attr_"angle"',
#  '0__fft_coefficient__coeff_74__attr_"imag"',
#  '0__fft_coefficient__coeff_74__attr_"real"',
#  '0__fft_coefficient__coeff_75__attr_"abs"',
#  '0__fft_coefficient__coeff_75__attr_"angle"',
#  '0__fft_coefficient__coeff_75__attr_"imag"',
#  '0__fft_coefficient__coeff_75__attr_"real"',
#  '0__fft_coefficient__coeff_76__attr_"abs"',
#  '0__fft_coefficient__coeff_76__attr_"angle"',
#  '0__fft_coefficient__coeff_76__attr_"imag"',
#  '0__fft_coefficient__coeff_76__attr_"real"',
#  '0__fft_coefficient__coeff_77__attr_"abs"',
#  '0__fft_coefficient__coeff_77__attr_"angle"',
#  '0__fft_coefficient__coeff_77__attr_"imag"',
#  '0__fft_coefficient__coeff_77__attr_"real"',
#  '0__fft_coefficient__coeff_78__attr_"abs"',
#  '0__fft_coefficient__coeff_78__attr_"angle"',
#  '0__fft_coefficient__coeff_78__attr_"imag"',
#  '0__fft_coefficient__coeff_78__attr_"real"',
#  '0__fft_coefficient__coeff_79__attr_"abs"',
#  '0__fft_coefficient__coeff_79__attr_"angle"',
#  '0__fft_coefficient__coeff_79__attr_"imag"',
#  '0__fft_coefficient__coeff_79__attr_"real"',
#  '0__fft_coefficient__coeff_7__attr_"abs"',
#  '0__fft_coefficient__coeff_7__attr_"angle"',
#  '0__fft_coefficient__coeff_7__attr_"imag"',
#  '0__fft_coefficient__coeff_7__attr_"real"',
#  '0__fft_coefficient__coeff_80__attr_"abs"',
#  '0__fft_coefficient__coeff_80__attr_"angle"',
#  '0__fft_coefficient__coeff_80__attr_"imag"',
#  '0__fft_coefficient__coeff_80__attr_"real"',
#  '0__fft_coefficient__coeff_81__attr_"abs"',
#  '0__fft_coefficient__coeff_81__attr_"angle"',
#  '0__fft_coefficient__coeff_81__attr_"imag"',
#  '0__fft_coefficient__coeff_81__attr_"real"',
#  '0__fft_coefficient__coeff_82__attr_"abs"',
#  '0__fft_coefficient__coeff_82__attr_"angle"',
#  '0__fft_coefficient__coeff_82__attr_"imag"',
#  '0__fft_coefficient__coeff_82__attr_"real"',
#  '0__fft_coefficient__coeff_83__attr_"abs"',
#  '0__fft_coefficient__coeff_83__attr_"angle"',
#  '0__fft_coefficient__coeff_83__attr_"imag"',
#  '0__fft_coefficient__coeff_83__attr_"real"',
#  '0__fft_coefficient__coeff_84__attr_"abs"',
#  '0__fft_coefficient__coeff_84__attr_"angle"',
#  '0__fft_coefficient__coeff_84__attr_"imag"',
#  '0__fft_coefficient__coeff_84__attr_"real"',
#  '0__fft_coefficient__coeff_85__attr_"abs"',
#  '0__fft_coefficient__coeff_85__attr_"angle"',
#  '0__fft_coefficient__coeff_85__attr_"imag"',
#  '0__fft_coefficient__coeff_85__attr_"real"',
#  '0__fft_coefficient__coeff_86__attr_"abs"',
#  '0__fft_coefficient__coeff_86__attr_"angle"',
#  '0__fft_coefficient__coeff_86__attr_"imag"',
#  '0__fft_coefficient__coeff_86__attr_"real"',
#  '0__fft_coefficient__coeff_87__attr_"abs"',
#  '0__fft_coefficient__coeff_87__attr_"angle"',
#  '0__fft_coefficient__coeff_87__attr_"imag"',
#  '0__fft_coefficient__coeff_87__attr_"real"',
#  '0__fft_coefficient__coeff_88__attr_"abs"',
#  '0__fft_coefficient__coeff_88__attr_"angle"',
#  '0__fft_coefficient__coeff_88__attr_"imag"',
#  '0__fft_coefficient__coeff_88__attr_"real"',
#  '0__fft_coefficient__coeff_89__attr_"abs"',
#  '0__fft_coefficient__coeff_89__attr_"angle"',
#  '0__fft_coefficient__coeff_89__attr_"imag"',
#  '0__fft_coefficient__coeff_89__attr_"real"',
#  '0__fft_coefficient__coeff_8__attr_"abs"',
#  '0__fft_coefficient__coeff_8__attr_"angle"',
#  '0__fft_coefficient__coeff_8__attr_"imag"',
#  '0__fft_coefficient__coeff_8__attr_"real"',
#  '0__fft_coefficient__coeff_90__attr_"abs"',
#  '0__fft_coefficient__coeff_90__attr_"angle"',
#  '0__fft_coefficient__coeff_90__attr_"imag"',
#  '0__fft_coefficient__coeff_90__attr_"real"',
#  '0__fft_coefficient__coeff_91__attr_"abs"',
#  '0__fft_coefficient__coeff_91__attr_"angle"',
#  '0__fft_coefficient__coeff_91__attr_"imag"',
#  '0__fft_coefficient__coeff_91__attr_"real"',
#  '0__fft_coefficient__coeff_92__attr_"abs"',
#  '0__fft_coefficient__coeff_92__attr_"angle"',
#  '0__fft_coefficient__coeff_92__attr_"imag"',
#  '0__fft_coefficient__coeff_92__attr_"real"',
#  '0__fft_coefficient__coeff_93__attr_"abs"',
#  '0__fft_coefficient__coeff_93__attr_"angle"',
#  '0__fft_coefficient__coeff_93__attr_"imag"',
#  '0__fft_coefficient__coeff_93__attr_"real"',
#  '0__fft_coefficient__coeff_94__attr_"abs"',
#  '0__fft_coefficient__coeff_94__attr_"angle"',
#  '0__fft_coefficient__coeff_94__attr_"imag"',
#  '0__fft_coefficient__coeff_94__attr_"real"',
#  '0__fft_coefficient__coeff_95__attr_"abs"',
#  '0__fft_coefficient__coeff_95__attr_"angle"',
#  '0__fft_coefficient__coeff_95__attr_"imag"',
#  '0__fft_coefficient__coeff_95__attr_"real"',
#  '0__fft_coefficient__coeff_96__attr_"abs"',
#  '0__fft_coefficient__coeff_96__attr_"angle"',
#  '0__fft_coefficient__coeff_96__attr_"imag"',
#  '0__fft_coefficient__coeff_96__attr_"real"',
#  '0__fft_coefficient__coeff_97__attr_"abs"',
#  '0__fft_coefficient__coeff_97__attr_"angle"',
#  '0__fft_coefficient__coeff_97__attr_"imag"',
#  '0__fft_coefficient__coeff_97__attr_"real"',
#  '0__fft_coefficient__coeff_98__attr_"abs"',
#  '0__fft_coefficient__coeff_98__attr_"angle"',
#  '0__fft_coefficient__coeff_98__attr_"imag"',
#  '0__fft_coefficient__coeff_98__attr_"real"',
#  '0__fft_coefficient__coeff_99__attr_"abs"',
#  '0__fft_coefficient__coeff_99__attr_"angle"',
#  '0__fft_coefficient__coeff_99__attr_"imag"',
#  '0__fft_coefficient__coeff_99__attr_"real"',
#  '0__fft_coefficient__coeff_9__attr_"abs"',
#  '0__fft_coefficient__coeff_9__attr_"angle"',
#  '0__fft_coefficient__coeff_9__attr_"imag"',
#  '0__fft_coefficient__coeff_9__attr_"real"',
#  '0__first_location_of_maximum',
#  '0__first_location_of_minimum',
#  '0__friedrich_coefficients__m_3__r_30__coeff_0',
#  '0__friedrich_coefficients__m_3__r_30__coeff_1',
#  '0__friedrich_coefficients__m_3__r_30__coeff_2',
#  '0__friedrich_coefficients__m_3__r_30__coeff_3',
#  '0__has_duplicate',
#  '0__has_duplicate_max',
#  '0__has_duplicate_min',
#  '0__index_mass_quantile__q_0.1',
#  '0__index_mass_quantile__q_0.2',
#  '0__index_mass_quantile__q_0.3',
#  '0__index_mass_quantile__q_0.4',
#  '0__index_mass_quantile__q_0.6',
#  '0__index_mass_quantile__q_0.7',
#  '0__index_mass_quantile__q_0.8',
#  '0__index_mass_quantile__q_0.9',
#  '0__kurtosis',
#  '0__large_standard_deviation__r_0.05',
#  '0__large_standard_deviation__r_0.1',
#  '0__large_standard_deviation__r_0.15000000000000002',
#  '0__large_standard_deviation__r_0.2',
#  '0__large_standard_deviation__r_0.25',
#  '0__large_standard_deviation__r_0.30000000000000004',
#  '0__large_standard_deviation__r_0.35000000000000003',
#  '0__large_standard_deviation__r_0.4',
#  '0__large_standard_deviation__r_0.45',
#  '0__large_standard_deviation__r_0.5',
#  '0__large_standard_deviation__r_0.55',
#  '0__large_standard_deviation__r_0.6000000000000001',
#  '0__large_standard_deviation__r_0.65',
#  '0__large_standard_deviation__r_0.7000000000000001',
#  '0__large_standard_deviation__r_0.75',
#  '0__large_standard_deviation__r_0.8',
#  '0__large_standard_deviation__r_0.8500000000000001',
#  '0__large_standard_deviation__r_0.9',
#  '0__large_standard_deviation__r_0.9500000000000001',
#  '0__last_location_of_maximum',
#  '0__last_location_of_minimum',
#  '0__length',
#  '0__linear_trend__attr_"intercept"',
#  '0__linear_trend__attr_"pvalue"',
#  '0__linear_trend__attr_"rvalue"',
#  '0__linear_trend__attr_"slope"',
#  '0__linear_trend__attr_"stderr"',
#  '0__longest_strike_above_mean',
#  '0__longest_strike_below_mean',
#  '0__max_langevin_fixed_point__m_3__r_30',
#  '0__maximum',
#  '0__mean',
#  '0__mean_abs_change',
#  '0__mean_change',
#  '0__mean_second_derivative_central',
#  '0__median',
#  '0__minimum',
#  '0__number_crossing_m__m_-1',
#  '0__number_crossing_m__m_0',
#  '0__number_crossing_m__m_1',
#  '0__number_cwt_peaks__n_1',
#  '0__number_cwt_peaks__n_5',
#  '0__number_peaks__n_1',
#  '0__number_peaks__n_10',
#  '0__number_peaks__n_3',
#  '0__number_peaks__n_5',
#  '0__number_peaks__n_50',
#  '0__partial_autocorrelation__lag_0',
#  '0__partial_autocorrelation__lag_1',
#  '0__partial_autocorrelation__lag_2',
#  '0__partial_autocorrelation__lag_3',
#  '0__partial_autocorrelation__lag_4',
#  '0__partial_autocorrelation__lag_5',
#  '0__partial_autocorrelation__lag_6',
#  '0__partial_autocorrelation__lag_7',
#  '0__partial_autocorrelation__lag_8',
#  '0__partial_autocorrelation__lag_9',
#  '0__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  '0__percentage_of_reoccurring_values_to_all_values',
#  '0__quantile__q_0.1',
#  '0__quantile__q_0.2',
#  '0__quantile__q_0.3',
#  '0__quantile__q_0.4',
#  '0__quantile__q_0.6',
#  '0__quantile__q_0.7',
#  '0__quantile__q_0.8',
#  '0__quantile__q_0.9',
#  '0__range_count__max_0__min_1000000000000.0',
#  '0__range_count__max_1000000000000.0__min_0',
#  '0__range_count__max_1__min_-1',
#  '0__ratio_beyond_r_sigma__r_0.5',
#  '0__ratio_beyond_r_sigma__r_1',
#  '0__ratio_beyond_r_sigma__r_1.5',
#  '0__ratio_beyond_r_sigma__r_10',
#  '0__ratio_beyond_r_sigma__r_2',
#  '0__ratio_beyond_r_sigma__r_2.5',
#  '0__ratio_beyond_r_sigma__r_3',
#  '0__ratio_beyond_r_sigma__r_5',
#  '0__ratio_beyond_r_sigma__r_6',
#  '0__ratio_beyond_r_sigma__r_7',
#  '0__ratio_value_number_to_time_series_length',
#  '0__sample_entropy',
#  '0__skewness',
#  '0__spkt_welch_density__coeff_2',
#  '0__spkt_welch_density__coeff_5',
#  '0__spkt_welch_density__coeff_8',
#  '0__standard_deviation',
#  '0__sum_of_reoccurring_data_points',
#  '0__sum_of_reoccurring_values',
#  '0__sum_values',
#  '0__symmetry_looking__r_0.0',
#  '0__symmetry_looking__r_0.05',
#  '0__symmetry_looking__r_0.1',
#  '0__symmetry_looking__r_0.15000000000000002',
#  '0__symmetry_looking__r_0.2',
#  '0__symmetry_looking__r_0.25',
#  '0__symmetry_looking__r_0.30000000000000004',
#  '0__symmetry_looking__r_0.35000000000000003',
#  '0__symmetry_looking__r_0.4',
#  '0__symmetry_looking__r_0.45',
#  '0__symmetry_looking__r_0.5',
#  '0__symmetry_looking__r_0.55',
#  '0__symmetry_looking__r_0.6000000000000001',
#  '0__symmetry_looking__r_0.65',
#  '0__symmetry_looking__r_0.7000000000000001',
#  '0__symmetry_looking__r_0.75',
#  '0__symmetry_looking__r_0.8',
#  '0__symmetry_looking__r_0.8500000000000001',
#  '0__symmetry_looking__r_0.9',
#  '0__symmetry_looking__r_0.9500000000000001',
#  '0__time_reversal_asymmetry_statistic__lag_1',
#  '0__time_reversal_asymmetry_statistic__lag_2',
#  '0__time_reversal_asymmetry_statistic__lag_3',
#  '0__value_count__value_-1',
#  '0__value_count__value_0',
#  '0__value_count__value_1',
#  '0__variance',
#  '0__variance_larger_than_standard_deviation',
#  '100__abs_energy',
#  '100__absolute_sum_of_changes',
#  '100__agg_autocorrelation__f_agg_"mean"__maxlag_40',
#  '100__agg_autocorrelation__f_agg_"median"__maxlag_40',
#  '100__agg_autocorrelation__f_agg_"var"__maxlag_40',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"stderr"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"intercept"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"rvalue"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"slope"',
#  '100__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"stderr"',
#  '100__approximate_entropy__m_2__r_0.1',
#  '100__approximate_entropy__m_2__r_0.3',
#  '100__approximate_entropy__m_2__r_0.5',
#  '100__approximate_entropy__m_2__r_0.7',
#  '100__approximate_entropy__m_2__r_0.9',
#  '100__ar_coefficient__k_10__coeff_0',
#  '100__ar_coefficient__k_10__coeff_1',
#  '100__ar_coefficient__k_10__coeff_2',
#  '100__ar_coefficient__k_10__coeff_3',
#  '100__ar_coefficient__k_10__coeff_4',
#  '100__augmented_dickey_fuller__autolag_"AIC"__attr_"pvalue"',
#  '100__augmented_dickey_fuller__autolag_"AIC"__attr_"teststat"',
#  '100__augmented_dickey_fuller__autolag_"AIC"__attr_"usedlag"',
#  '100__autocorrelation__lag_0',
#  '100__autocorrelation__lag_1',
#  '100__autocorrelation__lag_2',
#  '100__autocorrelation__lag_3',
#  '100__autocorrelation__lag_4',
#  '100__autocorrelation__lag_5',
#  '100__autocorrelation__lag_6',
#  '100__autocorrelation__lag_7',
#  '100__autocorrelation__lag_8',
#  '100__autocorrelation__lag_9',
#  '100__binned_entropy__max_bins_10',
#  '100__c3__lag_1',
#  '100__c3__lag_2',
#  '100__c3__lag_3',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.0',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.0',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.2',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.0',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.2',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.4',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.0',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.2',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.4',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.6',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.0',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.2',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.6',
#  '100__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.8',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.2',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.4',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.6',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  '100__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.0',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.2',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.6',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  '100__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.8',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.0',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.2',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.4',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.6',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#  '100__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.8',
#  '100__cid_ce__normalize_False',
#  '100__cid_ce__normalize_True',
#  '100__count_above_mean',
#  '100__count_below_mean',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_5',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_10',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_2',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_20',
#  '100__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_5',
#  '100__energy_ratio_by_chunks__num_segments_10__segment_focus_0',
#  '100__energy_ratio_by_chunks__num_segments_10__segment_focus_1',
#  '100__energy_ratio_by_chunks__num_segments_10__segment_focus_2',
#  '100__energy_ratio_by_chunks__num_segments_10__segment_focus_3',
#  '100__energy_ratio_by_chunks__num_segments_10__segment_focus_4',
#  '100__energy_ratio_by_chunks__num_segments_10__segment_focus_5',
#  '100__energy_ratio_by_chunks__num_segments_10__segment_focus_6',
#  '100__energy_ratio_by_chunks__num_segments_10__segment_focus_7',
#  '100__energy_ratio_by_chunks__num_segments_10__segment_focus_8',
#  '100__energy_ratio_by_chunks__num_segments_10__segment_focus_9',
#  '100__fft_aggregated__aggtype_"centroid"',
#  '100__fft_aggregated__aggtype_"kurtosis"',
#  '100__fft_aggregated__aggtype_"skew"',
#  '100__fft_aggregated__aggtype_"variance"',
#  '100__fft_coefficient__coeff_0__attr_"abs"',
#  '100__fft_coefficient__coeff_0__attr_"angle"',
#  '100__fft_coefficient__coeff_0__attr_"imag"',
#  '100__fft_coefficient__coeff_0__attr_"real"',
#  '100__fft_coefficient__coeff_10__attr_"abs"',
#  '100__fft_coefficient__coeff_10__attr_"angle"',
#  '100__fft_coefficient__coeff_10__attr_"imag"',
#  '100__fft_coefficient__coeff_10__attr_"real"',
#  '100__fft_coefficient__coeff_11__attr_"abs"',
#  '100__fft_coefficient__coeff_11__attr_"angle"',
#  '100__fft_coefficient__coeff_11__attr_"imag"',
#  '100__fft_coefficient__coeff_11__attr_"real"',
#  '100__fft_coefficient__coeff_12__attr_"abs"',
#  '100__fft_coefficient__coeff_12__attr_"angle"',
#  '100__fft_coefficient__coeff_12__attr_"imag"',
#  '100__fft_coefficient__coeff_12__attr_"real"',
#  '100__fft_coefficient__coeff_13__attr_"abs"',
#  '100__fft_coefficient__coeff_13__attr_"angle"',
#  '100__fft_coefficient__coeff_13__attr_"imag"',
#  '100__fft_coefficient__coeff_13__attr_"real"',
#  '100__fft_coefficient__coeff_14__attr_"abs"',
#  '100__fft_coefficient__coeff_14__attr_"angle"',
#  '100__fft_coefficient__coeff_14__attr_"imag"',
#  '100__fft_coefficient__coeff_14__attr_"real"',
#  '100__fft_coefficient__coeff_15__attr_"abs"',
#  '100__fft_coefficient__coeff_15__attr_"angle"',
#  '100__fft_coefficient__coeff_15__attr_"imag"',
#  '100__fft_coefficient__coeff_15__attr_"real"',
#  ...]

# %%
n=217
features = pd.DataFrame()
Mean=[]
Var=[]
aCF1=[]
Peak=[]
Entropy=[]
Cpoints=[]
for muni in listaMunicp:
    municipio=notificaciones['distrito_nombre']==muni
    notif_x_municp=notificaciones[municipio]
    notif_x_municp = notif_x_municp.reset_index(drop=True)
    notif_x_municp = notif_x_municp['incidencia']
    notif_x_municp = notif_x_municp.replace('nan', np.nan).fillna(0.000001)
    notif_x_municp = notif_x_municp.replace([np.inf, -np.inf], np.nan).fillna(0.000001)
    #Features
    mean=tsfresh.feature_extraction.feature_calculators.mean(notif_x_municp)
    var=tsfresh.feature_extraction.feature_calculators.variance(notif_x_municp)
    ACF1=tsfresh.feature_extraction.feature_calculators.autocorrelation(notif_x_municp,1)
    peak=tsfresh.feature_extraction.feature_calculators.number_peaks(notif_x_municp,20)
    entropy=tsfresh.feature_extraction.feature_calculators.sample_entropy(notif_x_municp)
    cpoints=tsfresh.feature_extraction.feature_calculators.number_crossing_m(notif_x_municp,5)
    Mean.append(mean)
    Var.append(var)
    aCF1.append(ACF1)
    Peak.append(peak)
    Entropy.append(entropy)
    Cpoints.append(cpoints)

# %%
data_tuples = list(zip(Mean,Var,aCF1,Peak,Entropy,Cpoints))
features = pd.DataFrame(data_tuples, columns =['Mean', 'Var', 'ACF1', 'Peak','Entropy','Cpoints']) 
# print the data 
features
# Out:
#          Mean           Var      ACF1  Peak   Entropy  Cpoints
# 0    0.000905  1.611986e-05  0.107032     0  0.106632        0
# 1    0.000296  5.676308e-06  0.239303     1  0.030300        0
# 2    0.000077  7.576950e-07 -0.007784     2  0.015151        0
# 3    0.000108  4.759114e-07 -0.024538     1  0.053312        0
# 4    0.001281  2.063770e-05  0.577031     2  0.241864        0
# 5    0.001421  5.716581e-05  0.500280     2  0.115673        0
# 6    0.000088  4.982328e-07  0.239190     1  0.030300        0
# 7    0.003822  1.658742e-04  0.586376     3  0.378349        0
# 8    0.000546  2.599463e-05  0.326880     1  0.022726        0
# 9    0.025630  7.950591e-03  0.910253     4  0.333025        0
# 10   0.001561  2.448904e-05  0.641828     1  0.319122        0
# 11   0.023248  2.762442e-03  0.937756     4  0.627055        0
# 12   0.002104  3.426009e-05  0.642061     4  0.351583        0
# 13   0.000693  8.041793e-06  0.668411     1  0.147166        0
# 14   0.000046  5.468153e-07 -0.003951     1  0.007576        0
# 15   0.000306  2.458755e-05 -0.003837     1  0.007576        0
# 16   0.002748  9.474504e-05  0.388009     4  0.316922        0
# 17   0.020877  6.753126e-03  0.827253     2  0.323854        0
# 18   0.003891  1.516622e-04  0.718267     4  0.366937        0
# 19   0.000224  2.145583e-06  0.147725     0  0.045442        0
# 20   0.000492  1.175026e-05 -0.020729     2  0.045682        0
# 21   0.006525  3.366970e-04  0.798781     4  0.546325        0
# 22   0.003913  2.021478e-04  0.935587     4  0.269776        0
# 23   0.000668  6.599273e-06  0.203974     3  0.209162        0
# 24   0.001490  4.169421e-05  0.394666     1  0.178794        0
# 25   0.000325  1.570899e-06  0.762251     1  0.171438        0
# 26   0.028535  8.565790e-03  0.925634     3  0.322353        0
# 27   0.000514  8.276431e-06  0.802546     1  0.084582        0
# 28   0.000585  5.369755e-06  0.439442     2  0.154013        0
# 29   0.000056  4.048974e-07 -0.007828     2  0.015151        0
# ..        ...           ...       ...   ...       ...      ...
# 187  0.000027  1.826465e-07 -0.004048     1  0.007576        0
# 188  0.001187  1.879113e-05  0.448075     3  0.269626        0
# 189  0.000417  6.796711e-06  0.435921     1  0.115545        0
# 190  0.000124  1.325685e-06  0.326815     1  0.022726        0
# 191  0.000329  9.416816e-06 -0.011579     1  0.022726        0
# 192  0.000668  1.266950e-05  0.419162     2  0.076186        0
# 193  0.000226  2.422287e-06  0.092635     2  0.045592        0
# 194  0.000397  6.806043e-06 -0.023365     1  0.045442        0
# 195  0.043200  1.510273e-02  0.891709     3  0.390568        0
# 196  0.018127  2.950815e-03  0.898555     3  0.331869        0
# 197  0.000102  2.703345e-06 -0.003877     1  0.007576        0
# 198  0.000157  6.408362e-06 -0.003856     1  0.007576        0
# 199  0.006389  3.399341e-04  0.880794     3  0.363354        0
# 200  0.008367  7.511116e-04  0.856942     4  0.402254        0
# 201  0.004605  2.253092e-04  0.755948     3  0.574767        0
# 202  0.001535  5.121500e-05  0.292357     0  0.099659        0
# 203  0.000527  7.890736e-06  0.541818     1  0.068136        0
# 204  0.000116  8.632555e-07  0.239229     0  0.030300        0
# 205  0.004600  2.624413e-04  0.754967     4  0.552615        0
# 206  0.000055  3.901073e-07 -0.007888     0  0.015151        0
# 207  0.000719  1.483813e-05  0.248203     2  0.083835        0
# 208  0.000056  8.083944e-07 -0.003927     1  0.007576        0
# 209  0.001024  1.844965e-05  0.519976     2  0.193846        0
# 210  0.000581  1.359190e-05  0.317858     2  0.068870        0
# 211  0.000163  5.644450e-07  0.173887     3  0.099028        0
# 212  0.044142  2.624272e-02  0.906120     4  0.315588        0
# 213  0.025941  5.800278e-03  0.917458     4  0.377807        0
# 214  0.000861  6.170978e-05  0.623907     2  0.038110        0
# 215  0.000246  1.571981e-06  0.013301     1  0.083991        0
# 216  0.001077  3.017067e-05  0.447699     1  0.092076        0
#
# [217 rows x 6 columns]

# %%
features.iloc[1]
# Out:
# Mean       0.000296
# Var        0.000006
# ACF1       0.239303
# Peak       1.000000
# Entropy    0.030300
# Cpoints    0.000000
# Name: 1, dtype: float64

# %%
#Distancias para kmeans
#Euclidean
f_euclidean_dist = np.zeros((n,n))
for i in range(0,n):
    #print("i",i)
    for j in range(1,n):
        #print("j",j)
        f_euclidean_dist[i,j] = euclidean(features.iloc[i].values.flatten(), features.iloc[j].values.flatten())
#RMSE
f_rmse_dist = np.zeros((n,n))
for i in range(0,n):
    #print("i",i)
    for j in range(0,n):
       # print("j",j)
        f_rmse_dist[i,j] = rmse(features.iloc[i].values.flatten(), features.iloc[j].values.flatten())
#Corr
#print(features.iloc[i].values.flatten())
#print(features.iloc[j].values.flatten())
print('-------------------------------')
f_corr_dist = np.zeros((n,n))
#for i in range(0,n):
   # print("i",i)
 #   for j in range(0,n):
  #      print("j",j)
    #    print(features.iloc[i].values.flatten())
     #   print(features.iloc[j].values.flatten())
      #  f_corr_dist[i,j] = corr(features.iloc[i].values.flatten(), features.iloc[j].values.flatten())
#scorr
f_scorr_dist = np.zeros((n,n))
for i in range(0,n):
    #print("i",i)
    for j in range(0,n):
       # print("j",j)
        f_scorr_dist[i,j] = scorr(features.iloc[i].values.flatten(), features.iloc[j].values.flatten())
#DTW
f_dtw_dist = np.zeros((n,n))
for i in range(0,n):
    #print("i",i)
    for j in range(0,n):
       # print("j",j)
        f_dtw_dist[i,j] = fast_DTW(features.iloc[i].values.flatten(), features.iloc[j].values.flatten())
# Out:
# -------------------------------

# %%
from yellowbrick.cluster import KElbowVisualizer
model = AgglomerativeClustering()
visualizer = KElbowVisualizer(model, k=(3,50),metric='distortion', timings=False)

visualizer.fit(f_scorr_dist)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')

# %%
k=9

# %%
km_euc = KMeans(n_clusters=k).fit_predict(f_euclidean_dist)
silhouette_avg=silhouette_score( f_euclidean_dist, km_euc)
print("KM + euclidian distance: ",silhouette_score( f_euclidean_dist, km_euc))
km_rmse = KMeans(n_clusters=k).fit_predict(f_rmse_dist)
print("KM + rmse distance: ",silhouette_score( f_rmse_dist, km_rmse))
#km_corr = KMeans(n_clusters=k).fit_predict(f_corr_dist)
#print("KM + corr distance: ",silhouette_score( f_corr_dist, km_corr))
#print("KM + corr distance: ",silhouette_score( f_corr_dist, 0.0))
km_scorr = KMeans(n_clusters=k).fit_predict(f_scorr_dist)
print("KM + scorr distance: ",silhouette_score( f_scorr_dist, km_scorr))
km_dtw = KMeans(n_clusters=k).fit_predict(f_dtw_dist)
print("KM + dtw distance: ",silhouette_score( f_dtw_dist, clusters))
# Out:
# KM + euclidian distance:  0.6559998122476823
# KM + rmse distance:  0.6613509624273096
# KM + scorr distance:  0.9953915258435644
# KM + dtw distance:  -0.29584107123155795
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/sklearn/cluster/_kmeans.py:1008: ConvergenceWarning: Number of distinct clusters (7) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_

# %%
#Experimentos HAC
HAC_euc = AgglomerativeClustering(n_clusters=k).fit_predict(f_euclidean_dist)
silhouette_avg=silhouette_score( f_euclidean_dist, HAC_euc)
print("HAC + euclidian distance: ",silhouette_score( f_euclidean_dist, HAC_euc))
HAC_rmse = AgglomerativeClustering(n_clusters=k).fit_predict(f_rmse_dist)
print("HAC + rmse distance: ",silhouette_score( f_rmse_dist, HAC_rmse))
#HAC_corr = AgglomerativeClustering(n_clusters=k).fit_predict(f_corr_dist)
#print("HAC + corr distance: ",silhouette_score( f_corr_dist,HAC_corr))
print("HAC + corr distance: ",0.0)
HAC_scorr = AgglomerativeClustering(n_clusters=k).fit_predict(f_scorr_dist)
print("HAC + scorr distance: ",silhouette_score( f_scorr_dist, HAC_scorr))
HAC_dtw = AgglomerativeClustering(n_clusters=k).fit_predict(f_dtw_dist)
print("HAC + dtw distance: ",silhouette_score( f_dtw_dist, HAC_dtw))
# Out:
# HAC + euclidian distance:  0.6385211824022649
# HAC + rmse distance:  0.6385439064812587
# HAC + corr distance:  0.0
# HAC + scorr distance:  0.3133639497304035
# HAC + dtw distance:  0.584638909649381
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
# /home/jbogado/virtualenv_3.5/lib/python3.5/site-packages/scipy/cluster/hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')

# %%
#Experimentos DBSCAN
DB_euc = DBSCAN(eps=3, min_samples=2).fit_predict(f_euclidean_dist)
silhouette_avg=silhouette_score( f_euclidean_dist, DB_euc)
print("DBSCAN + euclidian distance: ",silhouette_score( f_euclidean_dist, DB_euc))
DB_rmse = DBSCAN(eps=12, min_samples=10).fit_predict(f_rmse_dist)
#print("DBSCAN + rmse distance: ",silhouette_score( f_rmse_dist, DB_rmse))
#print("DBSCAN + rmse distance: ",0.00000000)
#DB_corr = DBSCAN(eps=3, min_samples=2).fit_predict(f_corr_dist)
#print("DBSCAN + corr distance: ",silhouette_score( f_corr_dist, DB_corr))
print("DBSCAN + corr distance: ",0.0)
DB_scorr = DBSCAN(eps=3, min_samples=2).fit_predict(f_scorr_dist)
print("DBSCAN + scorr distance: ",silhouette_score( f_scorr_dist, DB_scorr))
DB_dtw = DBSCAN(eps=3, min_samples=2).fit_predict(f_dtw_dist)
print("KM + dtw distance: ",silhouette_score( f_dtw_dist, DB_dtw))
# Out:
# DBSCAN + euclidian distance:  0.7327015254414699
# DBSCAN + corr distance:  0.0
# DBSCAN + scorr distance:  0.982667657643341
# KM + dtw distance:  0.6447434480812199
