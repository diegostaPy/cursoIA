# %%
import pandas as pd
import numpy as np
from sklearn import linear_model, model_selection

def predict():

  # Read the whole data from CSV
  data = pd.read_csv("math-students.csv", sep=";")

  # The column whose values must be predicted
  predict_column = "G3"

  # Limit the data in a set of columns. These are 
  # the important columns for this test
  study_data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]
  
  # Set the features (attributes) and the label
  # for the test. The label is the data we want
  # to predict
  features = np.array(study_data.drop([predict_column], axis=1))
  labels = np.array(data[predict_column])

  # Given the whole read data, split it into a set 
  # of trains and tests.
  # Trains: the data used to train the model
  # Tests: the data used to compare the results later
  features_train, features_test, labels_train, labels_test = model_selection.train_test_split(features, labels, test_size = 0.1)
  
  # Train the model drawing the line using Linear 
  # Regression concept. We use different concepts 
  # for different data (entry) formats
  linear = linear_model.LinearRegression()
  linear.fit(features_train, labels_train)

  # Check the accuracy of our model by comparing 
  # the results with the expected data (tests)
  accuracy = linear.score(features_test, labels_test)

  # Since we now have our model trained, we predict 
  # the labels (test ones) based on the features 
  # (also the test ones)
  predictions = linear.predict(features_test)

  # Print details
  for i in range(len(predictions)):
    print("features: .........", features_test[i])
    print("expected label: ...", labels_test[i])
    print("predicted label: ..", predictions[i])
    print("-")
  print("Accuracy:", (accuracy * 100), "%")

# %%
predict()
# Out:
# features: ......... [16 15  3  0 16]
# expected label: ... 15
# predicted label: .. 15.664229550134856
# -
# features: ......... [11 10  1  0  0]
# expected label: ... 10
# predicted label: .. 9.77355924269293
# -
# features: ......... [8 7 2 3 8]
# expected label: ... 8
# predicted label: .. 5.791048474810311
# -
# features: ......... [13 13  4  0  4]
# expected label: ... 12
# predicted label: .. 12.626725787529377
# -
# features: ......... [13 14  1  0  0]
# expected label: ... 13
# predicted label: .. 14.000332303563809
# -
# features: ......... [19 19  4  0  4]
# expected label: ... 20
# predicted label: .. 19.430881837564243
# -
# features: ......... [15 15  2  0  4]
# expected label: ... 15
# predicted label: .. 15.254282652507413
# -
# features: ......... [8 7 2 3 0]
# expected label: ... 0
# predicted label: .. 5.501025917787332
# -
# features: ......... [10 12  1  0  2]
# expected label: ... 12
# predicted label: .. 11.65012043989842
# -
# features: ......... [12 10  3  0 10]
# expected label: ... 12
# predicted label: .. 9.93124807691475
# -
# features: ......... [ 9  8  2  1 15]
# expected label: ... 8
# predicted label: .. 7.639312804370087
# -
# features: ......... [12 13  2  0  4]
# expected label: ... 13
# predicted label: .. 12.83156514958628
# -
# features: ......... [12 14  1  0  0]
# expected label: ... 15
# predicted label: .. 13.84566681732096
# -
# features: ......... [10 10  2  0  0]
# expected label: ... 10
# predicted label: .. 9.439141332300208
# -
# features: ......... [11 11  2  0  2]
# expected label: ... 10
# predicted label: .. 10.645672979895094
# -
# features: ......... [11 14  1  0  6]
# expected label: ... 14
# predicted label: .. 13.908518248845347
# -
# features: ......... [10 10  2  0  4]
# expected label: ... 10
# predicted label: .. 9.584152610811696
# -
# features: ......... [14 13  2  0  2]
# expected label: ... 13
# predicted label: .. 13.06839048281623
# -
# features: ......... [ 8 10  1  0  0]
# expected label: ... 11
# predicted label: .. 9.309562783964386
# -
# features: ......... [8 8 2 0 2]
# expected label: ... 8
# predicted label: .. 7.243594954877663
# -
# features: ......... [13 13  2  0 14]
# expected label: ... 14
# predicted label: .. 13.348758832107851
# -
# features: ......... [8 8 2 0 8]
# expected label: ... 6
# predicted label: .. 7.4611118726448975
# -
# features: ......... [18 16  3  0  0]
# expected label: ... 16
# predicted label: .. 16.37287593067089
# -
# features: ......... [18 19  1  0  6]
# expected label: ... 19
# predicted label: .. 19.887979263026764
# -
# features: ......... [16 17  1  0  4]
# expected label: ... 18
# predicted label: .. 17.54742160709273
# -
# features: ......... [9 9 1 2 8]
# expected label: ... 9
# predicted label: .. 8.314421721308388
# -
# features: ......... [10 13  4  0  6]
# expected label: ... 13
# predicted label: .. 12.235234968056579
# -
# features: ......... [13 13  2  0  0]
# expected label: ... 12
# predicted label: .. 12.84121935731764
# -
# features: ......... [ 9 10  3  0  9]
# expected label: ... 9
# predicted label: .. 9.430998798558335
# -
# features: ......... [12 11  2  0  2]
# expected label: ... 12
# predicted label: .. 10.800338466137942
# -
# features: ......... [11 12  3  1  4]
# expected label: ... 11
# predicted label: .. 11.287552425184497
# -
# features: ......... [8 7 2 0 4]
# expected label: ... 6
# predicted label: .. 6.336740072037111
# -
# features: ......... [15 14  2  0  8]
# expected label: ... 14
# predicted label: .. 14.419933408922606
# -
# features: ......... [7 0 1 1 0]
# expected label: ... 0
# predicted label: .. -0.8689422151541867
# -
# features: ......... [14 13  4  0  0]
# expected label: ... 14
# predicted label: .. 12.636379995260736
# -
# features: ......... [14 13  2  0  4]
# expected label: ... 13
# predicted label: .. 13.140896122071975
# -
# features: ......... [8 8 2 0 0]
# expected label: ... 9
# predicted label: .. 7.171089315621918
# -
# features: ......... [16 15  2  0  2]
# expected label: ... 15
# predicted label: .. 15.336442499494517
# -
# features: ......... [10  9  3  0  2]
# expected label: ... 9
# predicted label: .. 8.352534025309781
# -
# features: ......... [7 9 3 0 0]
# expected label: ... 8
# predicted label: .. 7.8160319273254935
# -
# Accuracy: 91.00754547532563 %

# %%
#FlagNaN=df.notafila.values.isnan()

# %%
df['calificacion']=df.notafila.values.split(",")[-1].split("-")[-1]
