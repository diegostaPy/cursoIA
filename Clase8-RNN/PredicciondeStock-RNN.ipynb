# %% [markdown]
# # Stock Predictor RNN
#
# Predicción de las acciones de Apple

# %% [markdown]
# ## Carga de datos
#
# Primero carguemos nuestra serie temporal: un historial de alrededor de 140 días del precio de las acciones de Apple. Luego, debemos realizar una serie de pasos de preprocesamiento para prepararlo para su uso con un modelo RNN. En primer lugar, es una buena práctica normalizar las series de tiempo, normalizando su rango. Esto nos ayuda a evitar problemas numéricos graves asociados con la forma en que las funciones de activación comunes (como tanh) transforman números muy grandes (positivos o negativos), además de ayudarnos a evitar problemas relacionados al calcular derivadas.
#
# Datos normalizados [0,1] [using this scikit function](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html).

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

dataset = np.loadtxt('data/normalized_apple_prices.csv')

# %% [markdown]
# Visualizacion de los datos

# %%
plt.plot(dataset)
plt.xlabel('tiempo')
plt.ylabel('serie normalizada')
# Out:
# Text(0, 0.5, 'serie normalizada')

# %% [markdown]
# ## Paso 2:  Cortando las series en secuencias
# Recuerde, nuestra serie de tiempo es una secuencia de números que podemos representar matemáticamente en general como
# $$s_{0},s_{1},s_{2},...,s_{P}$$
#
# donde $ s_ {p} $ es el valor numérico de la serie de tiempo en el período de tiempo $ p $ y donde $ P $ es la longitud total de la serie. Para aplicar nuestro RNN, tratamos el problema de predicción de series de tiempo como un problema de regresión, por lo que necesitamos usar una ventana deslizante para construir un conjunto de pares de entrada / salida asociados para retroceder. Este proceso está animado en el gif a continuación.
#
# <img src="images/timeseries_windowing_training.gif" width=600 height=600/>
#
# Por ejemplo, utilizando una ventana de tamaño T = 5 (como se ilustra en el gif anterior) producimos un conjunto de pares de entrada / salida como el que se muestra en la tabla a continuación.
#
# $$\begin{array}{c|c}
# \text{Input} & \text{Output}\\
# \hline \color{CornflowerBlue} {\langle s_{1},s_{2},s_{3},s_{4},s_{5}\rangle} & \color{Goldenrod}{ s_{6}} \\
# \ \color{CornflowerBlue} {\langle s_{2},s_{3},s_{4},s_{5},s_{6} \rangle } & \color{Goldenrod} {s_{7} } \\
# \color{CornflowerBlue}  {\vdots} & \color{Goldenrod} {\vdots}\\
# \color{CornflowerBlue} { \langle s_{P-5},s_{P-4},s_{P-3},s_{P-2},s_{P-1} \rangle } & \color{Goldenrod} {s_{P}}
# \end{array}$$
#
# Observe aquí que cada entrada es una secuencia (o vector) de longitud 4 (y en general tiene una longitud igual al tamaño de ventana T) mientras que cada salida correspondiente es un valor escalar. Observe también cómo, dada una serie de tiempo de longitud P y tamaño de ventana T = 5 como se muestra arriba, creamos P - 5 pares de entrada / salida. De manera más general, para un tamaño de ventana T creamos P - T tales pares.
#
# ¡Ahora veamos la serie de tiempo de entrada como se describe arriba!

# %%
### The function below transforms the input series and window-size into a set of input/output pairs for our RNN model
def window_transform_series(series,window_size):
    # containers for input/output pairs
    X = []
    y = []
    
    for i in range(window_size, len(series)):
        X.append(series[i - window_size:i])
        y.append(series[i])
        
        
    # reshape each 
    X = np.asarray(X)
    X.shape = (np.shape(X)[0:2])
    y = np.asarray(y)
    y.shape = (len(y),1)
    
    return X,y

# %%
# And now we can window the data using our windowing function
window_size = 7
X,y = window_transform_series(series = dataset,window_size = window_size)

# %% [markdown]
# ## Paso 3: Separar Train y Test
#
# Para realizar las pruebas adecuadas en nuestro conjunto de datos, cortaremos el último 1/3 para su validación (o prueba).
#
# Tenga en cuenta que aquí ** no ** dividimos el conjunto de datos * aleatoriamente * como se haría normalmente al validar un modelo de regresión. Esto se debe a que nuestros pares de entrada / salida * están relacionados temporalmente *. No queremos validar nuestro modelo entrenando en un subconjunto aleatorio de la serie y luego probando en otro subconjunto aleatorio, ya que esto simula el escenario en el que recibimos nuevos puntos * dentro del marco de tiempo de nuestro conjunto de entrenamiento *.
#
# Queremos entrenar en una parte sólida de la serie (en nuestro caso, los primeros 2/3 completos) y validar en una parte posterior (el último 1/3), ya que esto simula cómo predeciríamos los valores * futuros *. de una serie de tiempo.

# %%
# split our dataset into training / testing sets
train_test_split = int(np.ceil(2*len(y)/float(3)))   # set the split point

# partition the training set
X_train = X[:train_test_split,:]
y_train = y[:train_test_split]

# keep the last chunk for testing
X_test = X[train_test_split:,:]
y_test = y[train_test_split:]

# NOTE: to use keras's RNN LSTM module our input must be reshaped to [samples, window size, stepsize] 
X_train = np.asarray(np.reshape(X_train, (X_train.shape[0], window_size, 1)))
X_test = np.asarray(np.reshape(X_test, (X_test.shape[0], window_size, 1)))

# %% [markdown]
# ## Step 4:  Construir y entrenar una RNN
#
#
# Después de haber creado pares de entrada / salida a partir de nuestra serie de tiempo y cortar esto en conjuntos de entrenamiento / prueba, ahora podemos comenzar a configurar nuestro RNN. Usamos Keras para construir rápidamente un RNN de dos capas ocultas de las siguientes especificaciones
#
# - layer 1 uses an LSTM module with 5 hidden units (note here the input_shape = (window_size,1))
# - layer 2 uses a fully connected module with one unit
# - the 'mean_squared_error' loss should be used

# %%
# import keras network libraries
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM


# start with fixed random seed
np.random.seed(0)


# Build an RNN to perform regression on our time series input/output data
model = Sequential()
model.add(LSTM(5, input_shape=(window_size, 1)))
model.add(Dense(1))

optimizer = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)

# compile the model
model.compile(loss='mean_squared_error', optimizer=optimizer)

# %% [markdown]
# Ahora podemos entrenar el modelo

# %%
model.fit(X_train, y_train, epochs=500, batch_size=64, verbose=1)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 10s 26ms/step - loss: 0.1412
# Epoch 2/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1229
# Epoch 3/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1210
# Epoch 4/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1147
# Epoch 5/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1135
# Epoch 6/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1081
# Epoch 7/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1084
# Epoch 8/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0992
# Epoch 9/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1013
# Epoch 10/500
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0921
# Epoch 11/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0970
# Epoch 12/500
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0926
# Epoch 13/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0827
# Epoch 14/500
# 2/2 [==============================] - ETA: 0s - loss: 0.079 - 0s 20ms/step - loss: 0.0830
# Epoch 15/500
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0828
# Epoch 16/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0785
# Epoch 17/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0774
# Epoch 18/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0757
# Epoch 19/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0727
# Epoch 20/500
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0703
# Epoch 21/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0652
# Epoch 22/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0658
# Epoch 23/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0654
# Epoch 24/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0643
# Epoch 25/500
# 2/2 [==============================] - ETA: 0s - loss: 0.060 - 0s 14ms/step - loss: 0.0608
# Epoch 26/500
# 2/2 [==============================] - ETA: 0s - loss: 0.049 - 0s 13ms/step - loss: 0.0558
# Epoch 27/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0567
# Epoch 28/500
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0567
# Epoch 29/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0557
# Epoch 30/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0535
# Epoch 31/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0508
# Epoch 32/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0499
# Epoch 33/500
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0480
# Epoch 34/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0470
# Epoch 35/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0464
# Epoch 36/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0459
# Epoch 37/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0452
# Epoch 38/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0437
# Epoch 39/500
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0433
# Epoch 40/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0421
# Epoch 41/500
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0419
# Epoch 42/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0407
# Epoch 43/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0414
# Epoch 44/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0414
# Epoch 45/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0371
# Epoch 46/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0388
# Epoch 47/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0363
# Epoch 48/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0385
# Epoch 49/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0392
# Epoch 50/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0374
# Epoch 51/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0374
# Epoch 52/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0379
# Epoch 53/500
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0367
# Epoch 54/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0375
# Epoch 55/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0387
# Epoch 56/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0372
# Epoch 57/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0357
# Epoch 58/500
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0361
# Epoch 59/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0350
# Epoch 60/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0365
# Epoch 61/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0361
# Epoch 62/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0367
# Epoch 63/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0351
# Epoch 64/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0349
# Epoch 65/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0348
# Epoch 66/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0360
# Epoch 67/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0359
# Epoch 68/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0364
# Epoch 69/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0359
# Epoch 70/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0355
# Epoch 71/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0334
# Epoch 72/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0341
# Epoch 73/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0324
# Epoch 74/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0344
# Epoch 75/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0320
# Epoch 76/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0332
# Epoch 77/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0337
# Epoch 78/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0327
# Epoch 79/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0330
# Epoch 80/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0338
# Epoch 81/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0329
# Epoch 82/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0330
# Epoch 83/500
# 2/2 [==============================] - ETA: 0s - loss: 0.035 - 0s 8ms/step - loss: 0.0336
# Epoch 84/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0327
# Epoch 85/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0323
# Epoch 86/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0305
# Epoch 87/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0316
# Epoch 88/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0321
# Epoch 89/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0311
# Epoch 90/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0324
# Epoch 91/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0323
# Epoch 92/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0314
# Epoch 93/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0326
# Epoch 94/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0319
# Epoch 95/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0303
# Epoch 96/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0297
# Epoch 97/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0303
# Epoch 98/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0308
# Epoch 99/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0292
# Epoch 100/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0293
# Epoch 101/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0303
# Epoch 102/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0306
# Epoch 103/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0295
# Epoch 104/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0288
# Epoch 105/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0293
# Epoch 106/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0284
# Epoch 107/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0301
# Epoch 108/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0280
# Epoch 109/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0300
# Epoch 110/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0288
# Epoch 111/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0279
# Epoch 112/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0261
# Epoch 113/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0286
# Epoch 114/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0289
# Epoch 115/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0276
# Epoch 116/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0277
# Epoch 117/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0283
# Epoch 118/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0274
# Epoch 119/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0277
# Epoch 120/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0270
# Epoch 121/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0272
# Epoch 122/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0282
# Epoch 123/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0269
# Epoch 124/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0260
# Epoch 125/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0267
# Epoch 126/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0280
# Epoch 127/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0258
# Epoch 128/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0242
# Epoch 129/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0253
# Epoch 130/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0267
# Epoch 131/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0267
# Epoch 132/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0253
# Epoch 133/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0254
# Epoch 134/500
# 2/2 [==============================] - ETA: 0s - loss: 0.025 - 0s 8ms/step - loss: 0.0253
# Epoch 135/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0255
# Epoch 136/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0252
# Epoch 137/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0253
# Epoch 138/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0236
# Epoch 139/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0239
# Epoch 140/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0237
# Epoch 141/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0241
# Epoch 142/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0246
# Epoch 143/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0230
# Epoch 144/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0249
# Epoch 145/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0245
# Epoch 146/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0250
# Epoch 147/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0236
# Epoch 148/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0237
# Epoch 149/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0237
# Epoch 150/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0221
# Epoch 151/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0223
# Epoch 152/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0236
# Epoch 153/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0229
# Epoch 154/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0235
# Epoch 155/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0218
# Epoch 156/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0208
# Epoch 157/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0223
# Epoch 158/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0220
# Epoch 159/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0216
# Epoch 160/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0219
# Epoch 161/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0214
# Epoch 162/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0224
# Epoch 163/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0221
# Epoch 164/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0216
# Epoch 165/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0221
# Epoch 166/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0222
# Epoch 167/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0216
# Epoch 168/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0205
# Epoch 169/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0203
# Epoch 170/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0220
# Epoch 171/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0208
# Epoch 172/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0206
# Epoch 173/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0206
# Epoch 174/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0189
# Epoch 175/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0212
# Epoch 176/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0193
# Epoch 177/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0200
# Epoch 178/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0188
# Epoch 179/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0203
# Epoch 180/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0193
# Epoch 181/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0207
# Epoch 182/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0197
# Epoch 183/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0206
# Epoch 184/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0180
# Epoch 185/500
# 2/2 [==============================] - ETA: 0s - loss: 0.016 - 0s 11ms/step - loss: 0.0185
# Epoch 186/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0199
# Epoch 187/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0193
# Epoch 188/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0204
# Epoch 189/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0200
# Epoch 190/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0183
# Epoch 191/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0192
# Epoch 192/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0196
# Epoch 193/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0193
# Epoch 194/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0183
# Epoch 195/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0192
# Epoch 196/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0187
# Epoch 197/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0186
# Epoch 198/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0201
# Epoch 199/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0192
# Epoch 200/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0189
# Epoch 201/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0186
# Epoch 202/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0192
# Epoch 203/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0191
# Epoch 204/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0184
# Epoch 205/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0189
# Epoch 206/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0189
# Epoch 207/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0190
# Epoch 208/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0182
# Epoch 209/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0186
# Epoch 210/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0191
# Epoch 211/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0190
# Epoch 212/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0168
# Epoch 213/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0184
# Epoch 214/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0182
# Epoch 215/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0190
# Epoch 216/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0180
# Epoch 217/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0191
# Epoch 218/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0182
# Epoch 219/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0164
# Epoch 220/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0174
# Epoch 221/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0178
# Epoch 222/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0177
# Epoch 223/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0183
# Epoch 224/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0180
# Epoch 225/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0177
# Epoch 226/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0181
# Epoch 227/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0173
# Epoch 228/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0172
# Epoch 229/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0180
# Epoch 230/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0184
# Epoch 231/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0183
# Epoch 232/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0178
# Epoch 233/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0177
# Epoch 234/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 235/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0158
# Epoch 236/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0178
# Epoch 237/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0182
# Epoch 238/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0175
# Epoch 239/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170
# Epoch 240/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0180
# Epoch 241/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0178
# Epoch 242/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0172
# Epoch 243/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170
# Epoch 244/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0172
# Epoch 245/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0174
# Epoch 246/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0177
# Epoch 247/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 248/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0177
# Epoch 249/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0176
# Epoch 250/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0174
# Epoch 251/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0182
# Epoch 252/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0187
# Epoch 253/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 254/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0176
# Epoch 255/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0181
# Epoch 256/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0177
# Epoch 257/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0175
# Epoch 258/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0174
# Epoch 259/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0185
# Epoch 260/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0172
# Epoch 261/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0184
# Epoch 262/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0174
# Epoch 263/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0171
# Epoch 264/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0175
# Epoch 265/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0180
# Epoch 266/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 267/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0174
# Epoch 268/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0172
# Epoch 269/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 270/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0176
# Epoch 271/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 272/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0171
# Epoch 273/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0170
# Epoch 274/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0175
# Epoch 275/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0176
# Epoch 276/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0172
# Epoch 277/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0184
# Epoch 278/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0178
# Epoch 279/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0171
# Epoch 280/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0168
# Epoch 281/500
# 2/2 [==============================] - ETA: 0s - loss: 0.019 - 0s 5ms/step - loss: 0.0181
# Epoch 282/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0179
# Epoch 283/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0159
# Epoch 284/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0176
# Epoch 285/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0181
# Epoch 286/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0165
# Epoch 287/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0179
# Epoch 288/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0180
# Epoch 289/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0167
# Epoch 290/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0181
# Epoch 291/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0180
# Epoch 292/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0168
# Epoch 293/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0178
# Epoch 294/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0173
# Epoch 295/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0174
# Epoch 296/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0168
# Epoch 297/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0172
# Epoch 298/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0178
# Epoch 299/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0171
# Epoch 300/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0179
# Epoch 301/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0175
# Epoch 302/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0171
# Epoch 303/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0167
# Epoch 304/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0168
# Epoch 305/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0173
# Epoch 306/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0171
# Epoch 307/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0172
# Epoch 308/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0175
# Epoch 309/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0167
# Epoch 310/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0181
# Epoch 311/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0161
# Epoch 312/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0179
# Epoch 313/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0179
# Epoch 314/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0177
# Epoch 315/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0165
# Epoch 316/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0171
# Epoch 317/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0163
# Epoch 318/500
# 2/2 [==============================] - ETA: 0s - loss: 0.018 - 0s 4ms/step - loss: 0.0176
# Epoch 319/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0176
# Epoch 320/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0166
# Epoch 321/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0170
# Epoch 322/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0174
# Epoch 323/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0178
# Epoch 324/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0176
# Epoch 325/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0174
# Epoch 326/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0176
# Epoch 327/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0174
# Epoch 328/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0179
# Epoch 329/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0166
# Epoch 330/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0161
# Epoch 331/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0180
# Epoch 332/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0173
# Epoch 333/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0166
# Epoch 334/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0160
# Epoch 335/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0167
# Epoch 336/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0163
# Epoch 337/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0173
# Epoch 338/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0174
# Epoch 339/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0178
# Epoch 340/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0168
# Epoch 341/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0179
# Epoch 342/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0169
# Epoch 343/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0165
# Epoch 344/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0178
# Epoch 345/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0175
# Epoch 346/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0169
# Epoch 347/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0164
# Epoch 348/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0182
# Epoch 349/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0174
# Epoch 350/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0173
# Epoch 351/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0162
# Epoch 352/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0178
# Epoch 353/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0175
# Epoch 354/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0169
# Epoch 355/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170
# Epoch 356/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0173
# Epoch 357/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0171
# Epoch 358/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0177
# Epoch 359/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0180
# Epoch 360/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0164
# Epoch 361/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0166
# Epoch 362/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0171
# Epoch 363/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0162
# Epoch 364/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0173
# Epoch 365/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0176
# Epoch 366/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0168
# Epoch 367/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0172
# Epoch 368/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0169
# Epoch 369/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0168
# Epoch 370/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170
# Epoch 371/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0161
# Epoch 372/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0170
# Epoch 373/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 374/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0158
# Epoch 375/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0168
# Epoch 376/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0172
# Epoch 377/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0171
# Epoch 378/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170
# Epoch 379/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0165
# Epoch 380/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0172
# Epoch 381/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0166
# Epoch 382/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0158
# Epoch 383/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0167
# Epoch 384/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0168
# Epoch 385/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0161
# Epoch 386/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0174
# Epoch 387/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0174
# Epoch 388/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0170
# Epoch 389/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0171
# Epoch 390/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0163
# Epoch 391/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0167
# Epoch 392/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0164
# Epoch 393/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0170
# Epoch 394/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0164
# Epoch 395/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0158
# Epoch 396/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 397/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0169
# Epoch 398/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0172
# Epoch 399/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0175
# Epoch 400/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0162
# Epoch 401/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0166
# Epoch 402/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0168
# Epoch 403/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0168
# Epoch 404/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0171
# Epoch 405/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0168
# Epoch 406/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0173
# Epoch 407/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170
# Epoch 408/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0177
# Epoch 409/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0160
# Epoch 410/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0162
# Epoch 411/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0174
# Epoch 412/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0175
# Epoch 413/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0166
# Epoch 414/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0163
# Epoch 415/500
# 2/2 [==============================] - ETA: 0s - loss: 0.019 - 0s 4ms/step - loss: 0.0176
# Epoch 416/500
# 2/2 [==============================] - ETA: 0s - loss: 0.019 - 0s 4ms/step - loss: 0.0176
# Epoch 417/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170
# Epoch 418/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0165
# Epoch 419/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0154
# Epoch 420/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0163
# Epoch 421/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0165
# Epoch 422/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0169
# Epoch 423/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 424/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0172
# Epoch 425/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0154
# Epoch 426/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0170
# Epoch 427/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0156
# Epoch 428/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0166
# Epoch 429/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0163
# Epoch 430/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0165
# Epoch 431/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0164
# Epoch 432/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0170
# Epoch 433/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0177
# Epoch 434/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0172
# Epoch 435/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0164
# Epoch 436/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0169
# Epoch 437/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0161
# Epoch 438/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0165
# Epoch 439/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0162
# Epoch 440/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0168
# Epoch 441/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0173
# Epoch 442/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0167
# Epoch 443/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0175
# Epoch 444/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0163
# Epoch 445/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0162
# Epoch 446/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0170
# Epoch 447/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0172
# Epoch 448/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0174
# Epoch 449/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0159
# Epoch 450/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0161
# Epoch 451/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0168
# Epoch 452/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0167
# Epoch 453/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0171
# Epoch 454/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0158
# Epoch 455/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0163
# Epoch 456/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0168
# Epoch 457/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0171
# Epoch 458/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0165
# Epoch 459/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0159
# Epoch 460/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0162
# Epoch 461/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0160
# Epoch 462/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0168
# Epoch 463/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0150
# Epoch 464/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0161
# Epoch 465/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0170
# Epoch 466/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0166
# Epoch 467/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0172
# Epoch 468/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0161
# Epoch 469/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0167
# Epoch 470/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0170
# Epoch 471/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0161
# Epoch 472/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0158
# Epoch 473/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0163
# Epoch 474/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0159
# Epoch 475/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0166
# Epoch 476/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0162
# Epoch 477/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0174
# Epoch 478/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0161
# Epoch 479/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0169
# Epoch 480/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0165
# Epoch 481/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0159
# Epoch 482/500
# 2/2 [==============================] - ETA: 0s - loss: 0.016 - 0s 4ms/step - loss: 0.0165
# Epoch 483/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0161
# Epoch 484/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0169
# Epoch 485/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0168
# Epoch 486/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0169
# Epoch 487/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0173
# Epoch 488/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0169
# Epoch 489/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0155
# Epoch 490/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0151
# Epoch 491/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0171
# Epoch 492/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0150
# Epoch 493/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0172
# Epoch 494/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0168
# Epoch 495/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0161
# Epoch 496/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0169
# Epoch 497/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0165
# Epoch 498/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0152
# Epoch 499/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.0161
# Epoch 500/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0156

# %% [markdown]
# ## Paso 5: Verificando el modelo
#
#
# With our model fit we can now make predictions on both our training and testing sets.

# %%
# generate predictions for training
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
# print out training and testing errors
training_error = model.evaluate(X_train, y_train, verbose=0)
print('training error = ' + str(training_error))

testing_error = model.evaluate(X_test, y_test, verbose=0)
print('testing error = ' + str(testing_error))
# Out:
# training error = 0.016358334571123123
# testing error = 0.014403694309294224

# %%
### Plot everything - the original series as well as predictions on training and testing sets
import matplotlib.pyplot as plt
# %matplotlib inline

# plot original series
plt.plot(dataset,color = 'k')

# plot training set prediction
split_pt = train_test_split + window_size 
plt.plot(np.arange(window_size,split_pt,1),train_predict,color = 'b')

# plot testing set prediction
plt.plot(np.arange(split_pt,split_pt + len(test_predict),1),test_predict,color = 'r')

# pretty up graph
plt.xlabel('day')
plt.ylabel('(normalized) price of Apple stock')
plt.legend(['original series','training fit','testing fit'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
